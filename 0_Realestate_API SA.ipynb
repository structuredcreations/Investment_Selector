# %%
# The aim of this script is to download all rental property data and all available property from realestate website.
# the looping method doesn't work, hence the long winded version

# %%
# pip install -e git+https://github.com/tomquirk/realestate-com-au-api.git#egg=realestate_com_au_api

from realestate_com_au import RealestateComAu
api = RealestateComAu()

# Get property listings
# listings = api.search(locations=["seventeen seventy, qld 4677"], channel="buy", keywords=["tenant"], exclude_keywords=["pool"])

# %%
# https://www.matthewproctor.com/australian_postcodes
# df_postcode = pd.read_excel (r'/Users/joezhou/Downloads/Realestate/australian_postcodes.xlsx', sheet_name='Sheet1')

# sample test suburb
# df_postcode_subset = df_postcode.loc[(df_postcode['Locality']=='LIDCOMBE') & (df_postcode['Postcode']==2141) ]

# df_postcode_subset["VAR_Find"] = '["'+df_postcode_subset['Postcode'].apply(str)+","+df_postcode_subset['Locality']+'"]'
# list_postcode = list(df_postcode_subset['VAR_Find'].dropna())

# %%
import pandas as pd

# try a loop approach by suburb
#note: code below doesn't work for some reason, it returns an arbitary list of values

DF_RENT = pd.DataFrame()
DF_ALL = pd.DataFrame()

def DWN_INF(Find_Text):    
    global DF_RENT
    try:
        df_imp_rent = api.search(locations=Find_Text, channel="rent")
        df_imp_rent = pd.DataFrame(df_imp_rent)
        
        from datetime import datetime as dt
        dte = dt.now().strftime('%Y%m%d')
        fname = "/Users/joezhou/Downloads/loop_test{}.xlsx".format(dte)
        df_imp_rent.to_excel(fname)

        df_imp_all = api.search(locations=Find_Text)
        df_imp_all = pd.DataFrame(df_imp_all)

        DF_RENT = DF_RENT.append(df_imp_rent, ignore_index=True) 
        DF_ALL = DF_ALL.append(df_imp_all, ignore_index=True) 

        print("found for:",Find_Text)

    except Exception:
        print("Error with:",Find_Text)
        pass    
    return()

# Download all
# for Find_Var in list_postcode:
#    DWN_INF(Find_Var)

# %%
# SA - rental
DF_RENT = pd.DataFrame()

df_out = api.search(locations=['0872,AHERRENGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:0872-AHERRENGE")
df_out = api.search(locations=['5000,ADELAIDE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5000-ADELAIDE")
df_out = api.search(locations=['5006,NORTH ADELAIDE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5006-NORTH ADELAIDE")
df_out = api.search(locations=['5007,BOWDEN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5007-BOWDEN")
df_out = api.search(locations=['5008,CROYDON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5008-CROYDON")
df_out = api.search(locations=['5009,ALLENBY GARDENS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5009-ALLENBY GARDENS")
df_out = api.search(locations=['5010,ANGLE PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5010-ANGLE PARK")
df_out = api.search(locations=['5011,ST CLAIR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5011-ST CLAIR")
df_out = api.search(locations=['5012,ATHOL PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5012-ATHOL PARK")
df_out = api.search(locations=['5013,GILLMAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5013-GILLMAN")
df_out = api.search(locations=['5014,ALBERT PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5014-ALBERT PARK")
df_out = api.search(locations=['5015,BIRKENHEAD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5015-BIRKENHEAD")
df_out = api.search(locations=['5016,LARGS BAY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5016-LARGS BAY")
df_out = api.search(locations=['5017,OSBORNE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5017-OSBORNE")
df_out = api.search(locations=['5018,NORTH HAVEN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5018-NORTH HAVEN")
df_out = api.search(locations=['5019,EXETER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5019-EXETER")
df_out = api.search(locations=['5020,WEST LAKES SHORE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5020-WEST LAKES SHORE")
df_out = api.search(locations=['5021,WEST LAKES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5021-WEST LAKES")
df_out = api.search(locations=['5022,GRANGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5022-GRANGE")
df_out = api.search(locations=['5023,FINDON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5023-FINDON")
df_out = api.search(locations=['5024,FULHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5024-FULHAM")
df_out = api.search(locations=['5025,FLINDERS PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5025-FLINDERS PARK")
df_out = api.search(locations=['5031,MILE END'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5031-MILE END")
df_out = api.search(locations=['5032,BROOKLYN PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5032-BROOKLYN PARK")
df_out = api.search(locations=['5033,COWANDILLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5033-COWANDILLA")
df_out = api.search(locations=['5034,CLARENCE PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5034-CLARENCE PARK")
df_out = api.search(locations=['5035,ASHFORD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5035-ASHFORD")
df_out = api.search(locations=['5037,GLANDORE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5037-GLANDORE")
df_out = api.search(locations=['5038,CAMDEN PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5038-CAMDEN PARK")
df_out = api.search(locations=['5039,CLARENCE GARDENS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5039-CLARENCE GARDENS")
df_out = api.search(locations=['5040,NOVAR GARDENS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5040-NOVAR GARDENS")
df_out = api.search(locations=['5041,COLONEL LIGHT GARDENS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5041-COLONEL LIGHT GARDENS")
df_out = api.search(locations=['5042,BEDFORD PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5042-BEDFORD PARK")
df_out = api.search(locations=['5043,ASCOT PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5043-ASCOT PARK")
df_out = api.search(locations=['5044,GLENGOWRIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5044-GLENGOWRIE")
df_out = api.search(locations=['5045,GLENELG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5045-GLENELG")
df_out = api.search(locations=['5046,OAKLANDS PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5046-OAKLANDS PARK")
df_out = api.search(locations=['5047,DARLINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5047-DARLINGTON")
df_out = api.search(locations=['5048,BRIGHTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5048-BRIGHTON")
df_out = api.search(locations=['5049,KINGSTON PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5049-KINGSTON PARK")
df_out = api.search(locations=['5050,BELLEVUE HEIGHTS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5050-BELLEVUE HEIGHTS")
df_out = api.search(locations=['5051,BLACKWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5051-BLACKWOOD")
df_out = api.search(locations=['5052,BELAIR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5052-BELAIR")
df_out = api.search(locations=['5061,HYDE PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5061-HYDE PARK")
df_out = api.search(locations=['5062,BROWN HILL CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5062-BROWN HILL CREEK")
df_out = api.search(locations=['5063,EASTWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5063-EASTWOOD")
df_out = api.search(locations=['5064,GLEN OSMOND'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5064-GLEN OSMOND")
df_out = api.search(locations=['5065,DULWICH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5065-DULWICH")
df_out = api.search(locations=['5066,BEAUMONT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5066-BEAUMONT")
df_out = api.search(locations=['5067,BEULAH PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5067-BEULAH PARK")
df_out = api.search(locations=['5068,HEATHPOOL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5068-HEATHPOOL")
df_out = api.search(locations=['5069,COLLEGE PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5069-COLLEGE PARK")
df_out = api.search(locations=['5070,FELIXSTOW'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5070-FELIXSTOW")
df_out = api.search(locations=['5072,AULDANA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5072-AULDANA")
df_out = api.search(locations=['5073,HECTORVILLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5073-HECTORVILLE")
df_out = api.search(locations=['5074,CAMPBELLTOWN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5074-CAMPBELLTOWN")
df_out = api.search(locations=['5075,DERNANCOURT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5075-DERNANCOURT")
df_out = api.search(locations=['5076,ATHELSTONE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5076-ATHELSTONE")
df_out = api.search(locations=['5081,COLLINSWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5081-COLLINSWOOD")
df_out = api.search(locations=['5082,FITZROY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5082-FITZROY")
df_out = api.search(locations=['5083,BROADVIEW'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5083-BROADVIEW")
df_out = api.search(locations=['5084,BLAIR ATHOL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5084-BLAIR ATHOL")
df_out = api.search(locations=['5085,CLEARVIEW'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5085-CLEARVIEW")
df_out = api.search(locations=['5086,GILLES PLAINS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5086-GILLES PLAINS")
df_out = api.search(locations=['5087,KLEMZIG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5087-KLEMZIG")
df_out = api.search(locations=['5088,HOLDEN HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5088-HOLDEN HILL")
df_out = api.search(locations=['5089,HIGHBURY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5089-HIGHBURY")
df_out = api.search(locations=['5091,BANKSIA PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5091-BANKSIA PARK")
df_out = api.search(locations=['5092,MODBURY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5092-MODBURY")
df_out = api.search(locations=['5093,PARA VISTA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5093-PARA VISTA")
df_out = api.search(locations=['5094,CAVAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5094-CAVAN")
df_out = api.search(locations=['5095,MAWSON LAKES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5095-MAWSON LAKES")
df_out = api.search(locations=['5096,GULFVIEW HEIGHTS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5096-GULFVIEW HEIGHTS")
df_out = api.search(locations=['5097,REDWOOD PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5097-REDWOOD PARK")
df_out = api.search(locations=['5098,INGLE FARM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5098-INGLE FARM")
df_out = api.search(locations=['5106,PARAFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5106-PARAFIELD")
df_out = api.search(locations=['5107,GREEN FIELDS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5107-GREEN FIELDS")
df_out = api.search(locations=['5108,PARALOWIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5108-PARALOWIE")
df_out = api.search(locations=['5109,BRAHMA LODGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5109-BRAHMA LODGE")
df_out = api.search(locations=['5110,BOLIVAR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5110-BOLIVAR")
df_out = api.search(locations=['5111,EDINBURGH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5111-EDINBURGH")
df_out = api.search(locations=['5112,ELIZABETH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5112-ELIZABETH")
df_out = api.search(locations=['5113,DAVOREN PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5113-DAVOREN PARK")
df_out = api.search(locations=['5114,ANDREWS FARM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5114-ANDREWS FARM")
df_out = api.search(locations=['5115,KUDLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5115-KUDLA")
df_out = api.search(locations=['5116,EVANSTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5116-EVANSTON")
df_out = api.search(locations=['5117,ANGLE VALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5117-ANGLE VALE")
df_out = api.search(locations=['5118,BIBARINGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5118-BIBARINGA")
df_out = api.search(locations=['5120,BUCKLAND PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5120-BUCKLAND PARK")
df_out = api.search(locations=['5121,EYRE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5121-EYRE")
df_out = api.search(locations=['5125,GOLDEN GROVE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5125-GOLDEN GROVE")
df_out = api.search(locations=['5126,FAIRVIEW PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5126-FAIRVIEW PARK")
df_out = api.search(locations=['5127,WYNN VALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5127-WYNN VALE")
df_out = api.search(locations=['5131,HOUGHTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5131-HOUGHTON")
df_out = api.search(locations=['5132,PARACOMBE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5132-PARACOMBE")
df_out = api.search(locations=['5133,INGLEWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5133-INGLEWOOD")
df_out = api.search(locations=['5134,CHERRYVILLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5134-CHERRYVILLE")
df_out = api.search(locations=['5136,NORTON SUMMIT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5136-NORTON SUMMIT")
df_out = api.search(locations=['5137,ASHTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5137-ASHTON")
df_out = api.search(locations=['5138,BASKET RANGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5138-BASKET RANGE")
df_out = api.search(locations=['5139,FOREST RANGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5139-FOREST RANGE")
df_out = api.search(locations=['5140,GREENHILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5140-GREENHILL")
df_out = api.search(locations=['5141,HORSNELL GULLY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5141-HORSNELL GULLY")
df_out = api.search(locations=['5142,URAIDLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5142-URAIDLA")
df_out = api.search(locations=['5144,CAREY GULLY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5144-CAREY GULLY")
df_out = api.search(locations=['5150,EAGLE ON THE HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5150-EAGLE ON THE HILL")
df_out = api.search(locations=['5152,CLELAND'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5152-CLELAND")
df_out = api.search(locations=['5153,BIGGS FLAT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5153-BIGGS FLAT")
df_out = api.search(locations=['5154,ALDGATE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5154-ALDGATE")
df_out = api.search(locations=['5155,BRIDGEWATER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5155-BRIDGEWATER")
df_out = api.search(locations=['5156,UPPER STURT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5156-UPPER STURT")
df_out = api.search(locations=['5157,ASHBOURNE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5157-ASHBOURNE")
df_out = api.search(locations=['5158,HALLETT COVE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5158-HALLETT COVE")
df_out = api.search(locations=['5159,ABERFOYLE PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5159-ABERFOYLE PARK")
df_out = api.search(locations=['5160,LONSDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5160-LONSDALE")
df_out = api.search(locations=['5161,OLD REYNELLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5161-OLD REYNELLA")
df_out = api.search(locations=['5162,MORPHETT VALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5162-MORPHETT VALE")
df_out = api.search(locations=['5163,HACKHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5163-HACKHAM")
df_out = api.search(locations=['5164,CHRISTIE DOWNS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5164-CHRISTIE DOWNS")
df_out = api.search(locations=['5165,CHRISTIES BEACH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5165-CHRISTIES BEACH")
df_out = api.search(locations=['5166,O’SULLIVAN BEACH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5166-O’SULLIVAN BEACH")
df_out = api.search(locations=['5167,PORT NOARLUNGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5167-PORT NOARLUNGA")
df_out = api.search(locations=['5168,NOARLUNGA CENTRE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5168-NOARLUNGA CENTRE")
df_out = api.search(locations=['5169,MOANA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5169-MOANA")
df_out = api.search(locations=['5170,MASLIN BEACH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5170-MASLIN BEACH")
df_out = api.search(locations=['5171,BLEWITT SPRINGS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5171-BLEWITT SPRINGS")
df_out = api.search(locations=['5172,DINGABLEDINGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5172-DINGABLEDINGA")
df_out = api.search(locations=['5173,ALDINGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5173-ALDINGA")
df_out = api.search(locations=['5174,SELLICKS BEACH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5174-SELLICKS BEACH")
df_out = api.search(locations=['5201,BLACKFELLOWS CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5201-BLACKFELLOWS CREEK")
df_out = api.search(locations=['5202,HINDMARSH TIERS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5202-HINDMARSH TIERS")
df_out = api.search(locations=['5203,BALD HILLS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5203-BALD HILLS")
df_out = api.search(locations=['5204,CAPE JERVIS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5204-CAPE JERVIS")
df_out = api.search(locations=['5210,MOUNT COMPASS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5210-MOUNT COMPASS")
df_out = api.search(locations=['5211,BACK VALLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5211-BACK VALLEY")
df_out = api.search(locations=['5212,PORT ELLIOT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5212-PORT ELLIOT")
df_out = api.search(locations=['5213,MIDDLETON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5213-MIDDLETON")
df_out = api.search(locations=['5214,CURRENCY CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5214-CURRENCY CREEK")
df_out = api.search(locations=['5221,AMERICAN RIVER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5221-AMERICAN RIVER")
df_out = api.search(locations=['5222,AMERICAN BEACH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5222-AMERICAN BEACH")
df_out = api.search(locations=['5223,BAY OF SHOALS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5223-BAY OF SHOALS")
df_out = api.search(locations=['5231,CHAIN OF PONDS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5231-CHAIN OF PONDS")
df_out = api.search(locations=['5232,CUDLEE CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5232-CUDLEE CREEK")
df_out = api.search(locations=['5233,FORRESTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5233-FORRESTON")
df_out = api.search(locations=['5234,BIRDWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5234-BIRDWOOD")
df_out = api.search(locations=['5235,CROMER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5235-CROMER")
df_out = api.search(locations=['5236,TUNGKILLO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5236-TUNGKILLO")
df_out = api.search(locations=['5237,APAMURRA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5237-APAMURRA")
df_out = api.search(locations=['5238,ANGAS VALLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5238-ANGAS VALLEY")
df_out = api.search(locations=['5240,LENSWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5240-LENSWOOD")
df_out = api.search(locations=['5241,LOBETHAL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5241-LOBETHAL")
df_out = api.search(locations=['5242,BALHANNAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5242-BALHANNAH")
df_out = api.search(locations=['5243,OAKBANK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5243-OAKBANK")
df_out = api.search(locations=['5244,CHARLESTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5244-CHARLESTON")
df_out = api.search(locations=['5245,HAHNDORF'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5245-HAHNDORF")
df_out = api.search(locations=['5250,BLAKISTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5250-BLAKISTON")
df_out = api.search(locations=['5251,BUGLE RANGES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5251-BUGLE RANGES")
df_out = api.search(locations=['5252,BRUKUNGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5252-BRUKUNGA")
df_out = api.search(locations=['5253,AVOCA DELL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5253-AVOCA DELL")
df_out = api.search(locations=['5254,BUCCLEUCH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5254-BUCCLEUCH")
df_out = api.search(locations=['5255,ANGAS PLAINS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5255-ANGAS PLAINS")
df_out = api.search(locations=['5256,CLAYTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5256-CLAYTON")
df_out = api.search(locations=['5259,ASHVILLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5259-ASHVILLE")
df_out = api.search(locations=['5260,BAYAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5260-BAYAH")
df_out = api.search(locations=['5261,COOKE PLAINS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5261-COOKE PLAINS")
df_out = api.search(locations=['5262,BINNUM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5262-BINNUM")
df_out = api.search(locations=['5263,COONAWARRA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5263-COONAWARRA")
df_out = api.search(locations=['5264,COORONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5264-COORONG")
df_out = api.search(locations=['5265,COONALPYN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5265-COONALPYN")
df_out = api.search(locations=['5266,BUNBURY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5266-BUNBURY")
df_out = api.search(locations=['5267,BRIMBAGO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5267-BRIMBAGO")
df_out = api.search(locations=['5268,BANGHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5268-BANGHAM")
df_out = api.search(locations=['5269,CUSTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5269-CUSTON")
df_out = api.search(locations=['5270,BUCKINGHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5270-BUCKINGHAM")
df_out = api.search(locations=['5271,BOOL LAGOON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5271-BOOL LAGOON")
df_out = api.search(locations=['5272,COLES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5272-COLES")
df_out = api.search(locations=['5273,AVENUE RANGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5273-AVENUE RANGE")
df_out = api.search(locations=['5275,BLACKFORD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5275-BLACKFORD")
df_out = api.search(locations=['5276,BRAY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5276-BRAY")
df_out = api.search(locations=['5277,COMAUM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5277-COMAUM")
df_out = api.search(locations=['5278,KALANGADOO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5278-KALANGADOO")
df_out = api.search(locations=['5279,KOORINE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5279-KOORINE")
df_out = api.search(locations=['5280,BEACHPORT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5280-BEACHPORT")
df_out = api.search(locations=['5290,MOUNT GAMBIER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5290-MOUNT GAMBIER")
df_out = api.search(locations=['5291,ALLENDALE EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5291-ALLENDALE EAST")
df_out = api.search(locations=['5301,CARCUMA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5301-CARCUMA")
df_out = api.search(locations=['5302,LAMEROO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5302-LAMEROO")
df_out = api.search(locations=['5303,PARILLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5303-PARILLA")
df_out = api.search(locations=['5304,KARTE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5304-KARTE")
df_out = api.search(locations=['5306,WYNARKA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5306-WYNARKA")
df_out = api.search(locations=['5307,KAROONDA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5307-KAROONDA")
df_out = api.search(locations=['5308,COPEVILLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5308-COPEVILLE")
df_out = api.search(locations=['5309,BORRIKA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5309-BORRIKA")
df_out = api.search(locations=['5310,CALIPH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5310-CALIPH")
df_out = api.search(locations=['5311,ALAWOONA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5311-ALAWOONA")
df_out = api.search(locations=['5320,BEATTY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5320-BEATTY")
df_out = api.search(locations=['5321,CADELL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5321-CADELL")
df_out = api.search(locations=['5322,GOLDEN HEIGHTS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5322-GOLDEN HEIGHTS")
df_out = api.search(locations=['5330,BOOLGUN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5330-BOOLGUN")
df_out = api.search(locations=['5331,KINGSTON ON MURRAY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5331-KINGSTON ON MURRAY")
df_out = api.search(locations=['5332,MOOROOK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5332-MOOROOK")
df_out = api.search(locations=['5333,BOOKPURNONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5333-BOOKPURNONG")
df_out = api.search(locations=['5340,MUNDIC CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5340-MUNDIC CREEK")
df_out = api.search(locations=['5341,CALPERUM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5341-CALPERUM")
df_out = api.search(locations=['5342,MONASH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5342-MONASH")
df_out = api.search(locations=['5343,BERRI'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5343-BERRI")
df_out = api.search(locations=['5344,GLOSSOP'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5344-GLOSSOP")
df_out = api.search(locations=['5345,BARMERA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5345-BARMERA")
df_out = api.search(locations=['5346,COBDOGLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5346-COBDOGLA")
df_out = api.search(locations=['5350,ROSEDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5350-ROSEDALE")
df_out = api.search(locations=['5351,ALTONA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5351-ALTONA")
df_out = api.search(locations=['5352,BETHANY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5352-BETHANY")
df_out = api.search(locations=['5353,ANGASTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5353-ANGASTON")
df_out = api.search(locations=['5354,BAKARA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5354-BAKARA")
df_out = api.search(locations=['5355,DAVEYSTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5355-DAVEYSTON")
df_out = api.search(locations=['5356,ANNADALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5356-ANNADALE")
df_out = api.search(locations=['5357,BLANCHETOWN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5357-BLANCHETOWN")
df_out = api.search(locations=['5360,GREENOCK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5360-GREENOCK")
df_out = api.search(locations=['5371,MORN HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5371-MORN HILL")
df_out = api.search(locations=['5372,FREELING'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5372-FREELING")
df_out = api.search(locations=['5373,ALLENDALE NORTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5373-ALLENDALE NORTH")
df_out = api.search(locations=['5374,AUSTRALIA PLAINS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5374-AUSTRALIA PLAINS")
df_out = api.search(locations=['5381,BRADY CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5381-BRADY CREEK")
df_out = api.search(locations=['5400,MAGDALA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5400-MAGDALA")
df_out = api.search(locations=['5401,ALMA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5401-ALMA")
df_out = api.search(locations=['5410,LINWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5410-LINWOOD")
df_out = api.search(locations=['5411,GILES CORNER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5411-GILES CORNER")
df_out = api.search(locations=['5412,NAVAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5412-NAVAN")
df_out = api.search(locations=['5413,APOINGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5413-APOINGA")
df_out = api.search(locations=['5414,MANOORA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5414-MANOORA")
df_out = api.search(locations=['5415,MINTARO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5415-MINTARO")
df_out = api.search(locations=['5416,FARRELL FLAT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5416-FARRELL FLAT")
df_out = api.search(locations=['5417,BALAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5417-BALAH")
df_out = api.search(locations=['5418,COLLINSVILLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5418-COLLINSVILLE")
df_out = api.search(locations=['5419,CANOWIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5419-CANOWIE")
df_out = api.search(locations=['5420,CANOWIE BELT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5420-CANOWIE BELT")
df_out = api.search(locations=['5421,FRANKLYN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5421-FRANKLYN")
df_out = api.search(locations=['5422,CAVENAGH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5422-CAVENAGH")
df_out = api.search(locations=['5431,AMYTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5431-AMYTON")
df_out = api.search(locations=['5432,BARATTA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5432-BARATTA")
df_out = api.search(locations=['5433,BRUCE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5433-BRUCE")
df_out = api.search(locations=['5434,BARNDIOOTA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5434-BARNDIOOTA")
df_out = api.search(locations=['5440,ABMINGA STATION'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5440-ABMINGA STATION")
df_out = api.search(locations=['5451,AUBURN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5451-AUBURN")
df_out = api.search(locations=['5452,LEASINGHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5452-LEASINGHAM")
df_out = api.search(locations=['5453,ARMAGH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5453-ARMAGH")
df_out = api.search(locations=['5454,ANDREWS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5454-ANDREWS")
df_out = api.search(locations=['5455,HILLTOWN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5455-HILLTOWN")
df_out = api.search(locations=['5460,BARABBA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5460-BARABBA")
df_out = api.search(locations=['5461,BALAKLAVA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5461-BALAKLAVA")
df_out = api.search(locations=['5462,BLYTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5462-BLYTH")
df_out = api.search(locations=['5464,ANAMA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5464-ANAMA")
df_out = api.search(locations=['5470,YACKA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5470-YACKA")
df_out = api.search(locations=['5471,GULNARE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5471-GULNARE")
df_out = api.search(locations=['5472,GEORGETOWN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5472-GEORGETOWN")
df_out = api.search(locations=['5473,GLADSTONE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5473-GLADSTONE")
df_out = api.search(locations=['5480,APPILA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5480-APPILA")
df_out = api.search(locations=['5481,BANGOR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5481-BANGOR")
df_out = api.search(locations=['5482,BOOLEROO CENTRE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5482-BOOLEROO CENTRE")
df_out = api.search(locations=['5483,MELROSE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5483-MELROSE")
df_out = api.search(locations=['5485,WILMINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5485-WILMINGTON")
df_out = api.search(locations=['5490,CALTOWIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5490-CALTOWIE")
df_out = api.search(locations=['5491,BELALIE EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5491-BELALIE EAST")
df_out = api.search(locations=['5493,YONGALA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5493-YONGALA")
df_out = api.search(locations=['5495,BAROOTA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5495-BAROOTA")
df_out = api.search(locations=['5501,AVON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5501-AVON")
df_out = api.search(locations=['5502,FISCHER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5502-FISCHER")
df_out = api.search(locations=['5510,LOCHIEL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5510-LOCHIEL")
df_out = api.search(locations=['5520,BARUNGA GAP'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5520-BARUNGA GAP")
df_out = api.search(locations=['5521,REDHILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5521-REDHILL")
df_out = api.search(locations=['5522,FISHERMAN BAY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5522-FISHERMAN BAY")
df_out = api.search(locations=['5523,BEETALOO VALLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5523-BEETALOO VALLEY")
df_out = api.search(locations=['5540,BUNGAMA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5540-BUNGAMA")
df_out = api.search(locations=['5550,BEAUFORT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5550-BEAUFORT")
df_out = api.search(locations=['5552,KAINTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5552-KAINTON")
df_out = api.search(locations=['5554,BOORS PLAIN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5554-BOORS PLAIN")
df_out = api.search(locations=['5555,ALFORD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5555-ALFORD")
df_out = api.search(locations=['5556,NORTH BEACH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5556-NORTH BEACH")
df_out = api.search(locations=['5558,AGERY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5558-AGERY")
df_out = api.search(locations=['5560,BUTE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5560-BUTE")
df_out = api.search(locations=['5570,CLINTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5570-CLINTON")
df_out = api.search(locations=['5571,ARDROSSAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5571-ARDROSSAN")
df_out = api.search(locations=['5572,ARTHURTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5572-ARTHURTON")
df_out = api.search(locations=['5573,BALGOWAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5573-BALGOWAN")
df_out = api.search(locations=['5575,BLUFF BEACH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5575-BLUFF BEACH")
df_out = api.search(locations=['5576,HONITON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5576-HONITON")
df_out = api.search(locations=['5577,COUCH BEACH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5577-COUCH BEACH")
df_out = api.search(locations=['5580,CURRAMULKA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5580-CURRAMULKA")
df_out = api.search(locations=['5581,PORT VINCENT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5581-PORT VINCENT")
df_out = api.search(locations=['5582,PORT GILES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5582-PORT GILES")
df_out = api.search(locations=['5583,COOBOWIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5583-COOBOWIE")
df_out = api.search(locations=['5600,IRON BARON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5600-IRON BARON")
df_out = api.search(locations=['5601,BACKY POINT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5601-BACKY POINT")
df_out = api.search(locations=['5602,COWELL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5602-COWELL")
df_out = api.search(locations=['5603,ARNO BAY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5603-ARNO BAY")
df_out = api.search(locations=['5604,PORT NEILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5604-PORT NEILL")
df_out = api.search(locations=['5605,BUTLER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5605-BUTLER")
df_out = api.search(locations=['5606,KIRTON POINT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5606-KIRTON POINT")
df_out = api.search(locations=['5607,BOSTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5607-BOSTON")
df_out = api.search(locations=['5608,MULLAQUANA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5608-MULLAQUANA")
df_out = api.search(locations=['5609,COWLEDS LANDING'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5609-COWLEDS LANDING")
df_out = api.search(locations=['5611,COOYERDOO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5611-COOYERDOO")
df_out = api.search(locations=['5630,EDILILLIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5630-EDILILLIE")
df_out = api.search(locations=['5631,COCKALEECHIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5631-COCKALEECHIE")
df_out = api.search(locations=['5632,KAPINNIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5632-KAPINNIE")
df_out = api.search(locations=['5633,BOONERDO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5633-BOONERDO")
df_out = api.search(locations=['5640,CAMPOONA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5640-CAMPOONA")
df_out = api.search(locations=['5641,BARNA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5641-BARNA")
df_out = api.search(locations=['5642,DARKE PEAK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5642-DARKE PEAK")
df_out = api.search(locations=['5650,COOTRA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5650-COOTRA")
df_out = api.search(locations=['5651,KYANCUTTA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5651-KYANCUTTA")
df_out = api.search(locations=['5652,PANEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5652-PANEY")
df_out = api.search(locations=['5654,COCATA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5654-COCATA")
df_out = api.search(locations=['5655,BOCKELBERG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5655-BOCKELBERG")
df_out = api.search(locations=['5660,CHILPENUNDA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5660-CHILPENUNDA")
df_out = api.search(locations=['5661,KOOLGERA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5661-KOOLGERA")
df_out = api.search(locations=['5670,BRAMFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5670-BRAMFIELD")
df_out = api.search(locations=['5671,BAIRD BAY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5671-BAIRD BAY")
df_out = api.search(locations=['5680,CARAWA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5680-CARAWA")
df_out = api.search(locations=['5690,BOOKABIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5690-BOOKABIE")
df_out = api.search(locations=['5700,BLANCHE HARBOR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5700-BLANCHE HARBOR")
df_out = api.search(locations=['5701,ARKAROOLA VILLAGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5701-ARKAROOLA VILLAGE")
df_out = api.search(locations=['5710,COOK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5710-COOK")
df_out = api.search(locations=['5713,EMEROO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5713-EMEROO")
df_out = api.search(locations=['5715,CARRIEWERLOO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5715-CARRIEWERLOO")
df_out = api.search(locations=['5717,HILTABA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5717-HILTABA")
df_out = api.search(locations=['5719,BON BON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5719-BON BON")
df_out = api.search(locations=['5720,ARCOONA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5720-ARCOONA")
df_out = api.search(locations=['5722,ANDAMOOKA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5722-ANDAMOOKA")
df_out = api.search(locations=['5723,ALLANDALE STATION'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5723-ALLANDALE STATION")
df_out = api.search(locations=['5724,MARLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5724-MARLA")
df_out = api.search(locations=['5725,OLYMPIC DAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5725-OLYMPIC DAM")
df_out = api.search(locations=['5730,ALPANA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5730-ALPANA")
df_out = api.search(locations=['5731,BOLLARDS LAGOON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5731-BOLLARDS LAGOON")
df_out = api.search(locations=['5732,ANGEPENA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5732-ANGEPENA")
df_out = api.search(locations=['5733,ALTON DOWNS STATION'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5733-ALTON DOWNS STATION")
df_out = api.search(locations=['5734,CROWN POINT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5734-CROWN POINT")
df_out = api.search(locations=['5950,ADELAIDE AIRPORT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:5950-ADELAIDE AIRPORT")

DF_RENT1 = DF_RENT.reset_index()
DF_RENT2 = DF_RENT1.drop(columns=['id','index','images','images_floorplans','listers'])
DF_RENT_UNIQ = DF_RENT2.drop_duplicates()

DF_RENT_UNIQ.to_pickle("/Users/joezhou/Downloads/Realestate/R_RENT_SA.pkl")

# %%
# SA - all
DF_ALL = pd.DataFrame()

df_out = api.search(locations=['0872,AHERRENGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:0872-AHERRENGE")
df_out = api.search(locations=['5000,ADELAIDE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5000-ADELAIDE")
df_out = api.search(locations=['5006,NORTH ADELAIDE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5006-NORTH ADELAIDE")
df_out = api.search(locations=['5007,BOWDEN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5007-BOWDEN")
df_out = api.search(locations=['5008,CROYDON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5008-CROYDON")
df_out = api.search(locations=['5009,ALLENBY GARDENS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5009-ALLENBY GARDENS")
df_out = api.search(locations=['5010,ANGLE PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5010-ANGLE PARK")
df_out = api.search(locations=['5011,ST CLAIR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5011-ST CLAIR")
df_out = api.search(locations=['5012,ATHOL PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5012-ATHOL PARK")
df_out = api.search(locations=['5013,GILLMAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5013-GILLMAN")
df_out = api.search(locations=['5014,ALBERT PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5014-ALBERT PARK")
df_out = api.search(locations=['5015,BIRKENHEAD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5015-BIRKENHEAD")
df_out = api.search(locations=['5016,LARGS BAY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5016-LARGS BAY")
df_out = api.search(locations=['5017,OSBORNE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5017-OSBORNE")
df_out = api.search(locations=['5018,NORTH HAVEN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5018-NORTH HAVEN")
df_out = api.search(locations=['5019,EXETER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5019-EXETER")
df_out = api.search(locations=['5020,WEST LAKES SHORE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5020-WEST LAKES SHORE")
df_out = api.search(locations=['5021,WEST LAKES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5021-WEST LAKES")
df_out = api.search(locations=['5022,GRANGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5022-GRANGE")
df_out = api.search(locations=['5023,FINDON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5023-FINDON")
df_out = api.search(locations=['5024,FULHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5024-FULHAM")
df_out = api.search(locations=['5025,FLINDERS PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5025-FLINDERS PARK")
df_out = api.search(locations=['5031,MILE END'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5031-MILE END")
df_out = api.search(locations=['5032,BROOKLYN PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5032-BROOKLYN PARK")
df_out = api.search(locations=['5033,COWANDILLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5033-COWANDILLA")
df_out = api.search(locations=['5034,CLARENCE PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5034-CLARENCE PARK")
df_out = api.search(locations=['5035,ASHFORD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5035-ASHFORD")
df_out = api.search(locations=['5037,GLANDORE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5037-GLANDORE")
df_out = api.search(locations=['5038,CAMDEN PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5038-CAMDEN PARK")
df_out = api.search(locations=['5039,CLARENCE GARDENS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5039-CLARENCE GARDENS")
df_out = api.search(locations=['5040,NOVAR GARDENS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5040-NOVAR GARDENS")
df_out = api.search(locations=['5041,COLONEL LIGHT GARDENS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5041-COLONEL LIGHT GARDENS")
df_out = api.search(locations=['5042,BEDFORD PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5042-BEDFORD PARK")
df_out = api.search(locations=['5043,ASCOT PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5043-ASCOT PARK")
df_out = api.search(locations=['5044,GLENGOWRIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5044-GLENGOWRIE")
df_out = api.search(locations=['5045,GLENELG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5045-GLENELG")
df_out = api.search(locations=['5046,OAKLANDS PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5046-OAKLANDS PARK")
df_out = api.search(locations=['5047,DARLINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5047-DARLINGTON")
df_out = api.search(locations=['5048,BRIGHTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5048-BRIGHTON")
df_out = api.search(locations=['5049,KINGSTON PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5049-KINGSTON PARK")
df_out = api.search(locations=['5050,BELLEVUE HEIGHTS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5050-BELLEVUE HEIGHTS")
df_out = api.search(locations=['5051,BLACKWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5051-BLACKWOOD")
df_out = api.search(locations=['5052,BELAIR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5052-BELAIR")
df_out = api.search(locations=['5061,HYDE PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5061-HYDE PARK")
df_out = api.search(locations=['5062,BROWN HILL CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5062-BROWN HILL CREEK")
df_out = api.search(locations=['5063,EASTWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5063-EASTWOOD")
df_out = api.search(locations=['5064,GLEN OSMOND'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5064-GLEN OSMOND")
df_out = api.search(locations=['5065,DULWICH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5065-DULWICH")
df_out = api.search(locations=['5066,BEAUMONT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5066-BEAUMONT")
df_out = api.search(locations=['5067,BEULAH PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5067-BEULAH PARK")
df_out = api.search(locations=['5068,HEATHPOOL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5068-HEATHPOOL")
df_out = api.search(locations=['5069,COLLEGE PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5069-COLLEGE PARK")
df_out = api.search(locations=['5070,FELIXSTOW'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5070-FELIXSTOW")
df_out = api.search(locations=['5072,AULDANA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5072-AULDANA")
df_out = api.search(locations=['5073,HECTORVILLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5073-HECTORVILLE")
df_out = api.search(locations=['5074,CAMPBELLTOWN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5074-CAMPBELLTOWN")
df_out = api.search(locations=['5075,DERNANCOURT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5075-DERNANCOURT")
df_out = api.search(locations=['5076,ATHELSTONE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5076-ATHELSTONE")
df_out = api.search(locations=['5081,COLLINSWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5081-COLLINSWOOD")
df_out = api.search(locations=['5082,FITZROY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5082-FITZROY")
df_out = api.search(locations=['5083,BROADVIEW'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5083-BROADVIEW")
df_out = api.search(locations=['5084,BLAIR ATHOL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5084-BLAIR ATHOL")
df_out = api.search(locations=['5085,CLEARVIEW'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5085-CLEARVIEW")
df_out = api.search(locations=['5086,GILLES PLAINS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5086-GILLES PLAINS")
df_out = api.search(locations=['5087,KLEMZIG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5087-KLEMZIG")
df_out = api.search(locations=['5088,HOLDEN HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5088-HOLDEN HILL")
df_out = api.search(locations=['5089,HIGHBURY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5089-HIGHBURY")
df_out = api.search(locations=['5091,BANKSIA PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5091-BANKSIA PARK")
df_out = api.search(locations=['5092,MODBURY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5092-MODBURY")
df_out = api.search(locations=['5093,PARA VISTA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5093-PARA VISTA")
df_out = api.search(locations=['5094,CAVAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5094-CAVAN")
df_out = api.search(locations=['5095,MAWSON LAKES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5095-MAWSON LAKES")
df_out = api.search(locations=['5096,GULFVIEW HEIGHTS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5096-GULFVIEW HEIGHTS")
df_out = api.search(locations=['5097,REDWOOD PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5097-REDWOOD PARK")
df_out = api.search(locations=['5098,INGLE FARM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5098-INGLE FARM")
df_out = api.search(locations=['5106,PARAFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5106-PARAFIELD")
df_out = api.search(locations=['5107,GREEN FIELDS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5107-GREEN FIELDS")
df_out = api.search(locations=['5108,PARALOWIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5108-PARALOWIE")
df_out = api.search(locations=['5109,BRAHMA LODGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5109-BRAHMA LODGE")
df_out = api.search(locations=['5110,BOLIVAR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5110-BOLIVAR")
df_out = api.search(locations=['5111,EDINBURGH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5111-EDINBURGH")
df_out = api.search(locations=['5112,ELIZABETH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5112-ELIZABETH")
df_out = api.search(locations=['5113,DAVOREN PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5113-DAVOREN PARK")
df_out = api.search(locations=['5114,ANDREWS FARM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5114-ANDREWS FARM")
df_out = api.search(locations=['5115,KUDLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5115-KUDLA")
df_out = api.search(locations=['5116,EVANSTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5116-EVANSTON")
df_out = api.search(locations=['5117,ANGLE VALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5117-ANGLE VALE")
df_out = api.search(locations=['5118,BIBARINGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5118-BIBARINGA")
df_out = api.search(locations=['5120,BUCKLAND PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5120-BUCKLAND PARK")
df_out = api.search(locations=['5121,EYRE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5121-EYRE")
df_out = api.search(locations=['5125,GOLDEN GROVE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5125-GOLDEN GROVE")
df_out = api.search(locations=['5126,FAIRVIEW PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5126-FAIRVIEW PARK")
df_out = api.search(locations=['5127,WYNN VALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5127-WYNN VALE")
df_out = api.search(locations=['5131,HOUGHTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5131-HOUGHTON")
df_out = api.search(locations=['5132,PARACOMBE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5132-PARACOMBE")
df_out = api.search(locations=['5133,INGLEWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5133-INGLEWOOD")
df_out = api.search(locations=['5134,CHERRYVILLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5134-CHERRYVILLE")
df_out = api.search(locations=['5136,NORTON SUMMIT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5136-NORTON SUMMIT")
df_out = api.search(locations=['5137,ASHTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5137-ASHTON")
df_out = api.search(locations=['5138,BASKET RANGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5138-BASKET RANGE")
df_out = api.search(locations=['5139,FOREST RANGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5139-FOREST RANGE")
df_out = api.search(locations=['5140,GREENHILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5140-GREENHILL")
df_out = api.search(locations=['5141,HORSNELL GULLY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5141-HORSNELL GULLY")
df_out = api.search(locations=['5142,URAIDLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5142-URAIDLA")
df_out = api.search(locations=['5144,CAREY GULLY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5144-CAREY GULLY")
df_out = api.search(locations=['5150,EAGLE ON THE HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5150-EAGLE ON THE HILL")
df_out = api.search(locations=['5152,CLELAND'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5152-CLELAND")
df_out = api.search(locations=['5153,BIGGS FLAT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5153-BIGGS FLAT")
df_out = api.search(locations=['5154,ALDGATE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5154-ALDGATE")
df_out = api.search(locations=['5155,BRIDGEWATER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5155-BRIDGEWATER")
df_out = api.search(locations=['5156,UPPER STURT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5156-UPPER STURT")
df_out = api.search(locations=['5157,ASHBOURNE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5157-ASHBOURNE")
df_out = api.search(locations=['5158,HALLETT COVE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5158-HALLETT COVE")
df_out = api.search(locations=['5159,ABERFOYLE PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5159-ABERFOYLE PARK")
df_out = api.search(locations=['5160,LONSDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5160-LONSDALE")
df_out = api.search(locations=['5161,OLD REYNELLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5161-OLD REYNELLA")
df_out = api.search(locations=['5162,MORPHETT VALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5162-MORPHETT VALE")
df_out = api.search(locations=['5163,HACKHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5163-HACKHAM")
df_out = api.search(locations=['5164,CHRISTIE DOWNS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5164-CHRISTIE DOWNS")
df_out = api.search(locations=['5165,CHRISTIES BEACH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5165-CHRISTIES BEACH")
df_out = api.search(locations=['5166,O’SULLIVAN BEACH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5166-O’SULLIVAN BEACH")
df_out = api.search(locations=['5167,PORT NOARLUNGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5167-PORT NOARLUNGA")
df_out = api.search(locations=['5168,NOARLUNGA CENTRE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5168-NOARLUNGA CENTRE")
df_out = api.search(locations=['5169,MOANA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5169-MOANA")
df_out = api.search(locations=['5170,MASLIN BEACH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5170-MASLIN BEACH")
df_out = api.search(locations=['5171,BLEWITT SPRINGS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5171-BLEWITT SPRINGS")
df_out = api.search(locations=['5172,DINGABLEDINGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5172-DINGABLEDINGA")
df_out = api.search(locations=['5173,ALDINGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5173-ALDINGA")
df_out = api.search(locations=['5174,SELLICKS BEACH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5174-SELLICKS BEACH")
df_out = api.search(locations=['5201,BLACKFELLOWS CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5201-BLACKFELLOWS CREEK")
df_out = api.search(locations=['5202,HINDMARSH TIERS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5202-HINDMARSH TIERS")
df_out = api.search(locations=['5203,BALD HILLS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5203-BALD HILLS")
df_out = api.search(locations=['5204,CAPE JERVIS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5204-CAPE JERVIS")
df_out = api.search(locations=['5210,MOUNT COMPASS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5210-MOUNT COMPASS")
df_out = api.search(locations=['5211,BACK VALLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5211-BACK VALLEY")
df_out = api.search(locations=['5212,PORT ELLIOT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5212-PORT ELLIOT")
df_out = api.search(locations=['5213,MIDDLETON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5213-MIDDLETON")
df_out = api.search(locations=['5214,CURRENCY CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5214-CURRENCY CREEK")
df_out = api.search(locations=['5221,AMERICAN RIVER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5221-AMERICAN RIVER")
df_out = api.search(locations=['5222,AMERICAN BEACH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5222-AMERICAN BEACH")
df_out = api.search(locations=['5223,BAY OF SHOALS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5223-BAY OF SHOALS")
df_out = api.search(locations=['5231,CHAIN OF PONDS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5231-CHAIN OF PONDS")
df_out = api.search(locations=['5232,CUDLEE CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5232-CUDLEE CREEK")
df_out = api.search(locations=['5233,FORRESTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5233-FORRESTON")
df_out = api.search(locations=['5234,BIRDWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5234-BIRDWOOD")
df_out = api.search(locations=['5235,CROMER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5235-CROMER")
df_out = api.search(locations=['5236,TUNGKILLO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5236-TUNGKILLO")
df_out = api.search(locations=['5237,APAMURRA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5237-APAMURRA")
df_out = api.search(locations=['5238,ANGAS VALLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5238-ANGAS VALLEY")
df_out = api.search(locations=['5240,LENSWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5240-LENSWOOD")
df_out = api.search(locations=['5241,LOBETHAL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5241-LOBETHAL")
df_out = api.search(locations=['5242,BALHANNAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5242-BALHANNAH")
df_out = api.search(locations=['5243,OAKBANK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5243-OAKBANK")
df_out = api.search(locations=['5244,CHARLESTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5244-CHARLESTON")
df_out = api.search(locations=['5245,HAHNDORF'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5245-HAHNDORF")
df_out = api.search(locations=['5250,BLAKISTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5250-BLAKISTON")
df_out = api.search(locations=['5251,BUGLE RANGES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5251-BUGLE RANGES")
df_out = api.search(locations=['5252,BRUKUNGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5252-BRUKUNGA")
df_out = api.search(locations=['5253,AVOCA DELL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5253-AVOCA DELL")
df_out = api.search(locations=['5254,BUCCLEUCH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5254-BUCCLEUCH")
df_out = api.search(locations=['5255,ANGAS PLAINS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5255-ANGAS PLAINS")
df_out = api.search(locations=['5256,CLAYTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5256-CLAYTON")
df_out = api.search(locations=['5259,ASHVILLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5259-ASHVILLE")
df_out = api.search(locations=['5260,BAYAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5260-BAYAH")
df_out = api.search(locations=['5261,COOKE PLAINS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5261-COOKE PLAINS")
df_out = api.search(locations=['5262,BINNUM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5262-BINNUM")
df_out = api.search(locations=['5263,COONAWARRA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5263-COONAWARRA")
df_out = api.search(locations=['5264,COORONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5264-COORONG")
df_out = api.search(locations=['5265,COONALPYN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5265-COONALPYN")
df_out = api.search(locations=['5266,BUNBURY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5266-BUNBURY")
df_out = api.search(locations=['5267,BRIMBAGO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5267-BRIMBAGO")
df_out = api.search(locations=['5268,BANGHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5268-BANGHAM")
df_out = api.search(locations=['5269,CUSTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5269-CUSTON")
df_out = api.search(locations=['5270,BUCKINGHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5270-BUCKINGHAM")
df_out = api.search(locations=['5271,BOOL LAGOON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5271-BOOL LAGOON")
df_out = api.search(locations=['5272,COLES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5272-COLES")
df_out = api.search(locations=['5273,AVENUE RANGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5273-AVENUE RANGE")
df_out = api.search(locations=['5275,BLACKFORD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5275-BLACKFORD")
df_out = api.search(locations=['5276,BRAY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5276-BRAY")
df_out = api.search(locations=['5277,COMAUM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5277-COMAUM")
df_out = api.search(locations=['5278,KALANGADOO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5278-KALANGADOO")
df_out = api.search(locations=['5279,KOORINE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5279-KOORINE")
df_out = api.search(locations=['5280,BEACHPORT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5280-BEACHPORT")
df_out = api.search(locations=['5290,MOUNT GAMBIER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5290-MOUNT GAMBIER")
df_out = api.search(locations=['5291,ALLENDALE EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5291-ALLENDALE EAST")
df_out = api.search(locations=['5301,CARCUMA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5301-CARCUMA")
df_out = api.search(locations=['5302,LAMEROO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5302-LAMEROO")
df_out = api.search(locations=['5303,PARILLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5303-PARILLA")
df_out = api.search(locations=['5304,KARTE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5304-KARTE")
df_out = api.search(locations=['5306,WYNARKA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5306-WYNARKA")
df_out = api.search(locations=['5307,KAROONDA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5307-KAROONDA")
df_out = api.search(locations=['5308,COPEVILLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5308-COPEVILLE")
df_out = api.search(locations=['5309,BORRIKA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5309-BORRIKA")
df_out = api.search(locations=['5310,CALIPH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5310-CALIPH")
df_out = api.search(locations=['5311,ALAWOONA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5311-ALAWOONA")
df_out = api.search(locations=['5320,BEATTY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5320-BEATTY")
df_out = api.search(locations=['5321,CADELL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5321-CADELL")
df_out = api.search(locations=['5322,GOLDEN HEIGHTS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5322-GOLDEN HEIGHTS")
df_out = api.search(locations=['5330,BOOLGUN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5330-BOOLGUN")
df_out = api.search(locations=['5331,KINGSTON ON MURRAY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5331-KINGSTON ON MURRAY")
df_out = api.search(locations=['5332,MOOROOK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5332-MOOROOK")
df_out = api.search(locations=['5333,BOOKPURNONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5333-BOOKPURNONG")
df_out = api.search(locations=['5340,MUNDIC CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5340-MUNDIC CREEK")
df_out = api.search(locations=['5341,CALPERUM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5341-CALPERUM")
df_out = api.search(locations=['5342,MONASH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5342-MONASH")
df_out = api.search(locations=['5343,BERRI'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5343-BERRI")
df_out = api.search(locations=['5344,GLOSSOP'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5344-GLOSSOP")
df_out = api.search(locations=['5345,BARMERA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5345-BARMERA")
df_out = api.search(locations=['5346,COBDOGLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5346-COBDOGLA")
df_out = api.search(locations=['5350,ROSEDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5350-ROSEDALE")
df_out = api.search(locations=['5351,ALTONA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5351-ALTONA")
df_out = api.search(locations=['5352,BETHANY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5352-BETHANY")
df_out = api.search(locations=['5353,ANGASTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5353-ANGASTON")
df_out = api.search(locations=['5354,BAKARA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5354-BAKARA")
df_out = api.search(locations=['5355,DAVEYSTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5355-DAVEYSTON")
df_out = api.search(locations=['5356,ANNADALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5356-ANNADALE")
df_out = api.search(locations=['5357,BLANCHETOWN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5357-BLANCHETOWN")
df_out = api.search(locations=['5360,GREENOCK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5360-GREENOCK")
df_out = api.search(locations=['5371,MORN HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5371-MORN HILL")
df_out = api.search(locations=['5372,FREELING'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5372-FREELING")
df_out = api.search(locations=['5373,ALLENDALE NORTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5373-ALLENDALE NORTH")
df_out = api.search(locations=['5374,AUSTRALIA PLAINS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5374-AUSTRALIA PLAINS")
df_out = api.search(locations=['5381,BRADY CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5381-BRADY CREEK")
df_out = api.search(locations=['5400,MAGDALA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5400-MAGDALA")
df_out = api.search(locations=['5401,ALMA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5401-ALMA")
df_out = api.search(locations=['5410,LINWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5410-LINWOOD")
df_out = api.search(locations=['5411,GILES CORNER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5411-GILES CORNER")
df_out = api.search(locations=['5412,NAVAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5412-NAVAN")
df_out = api.search(locations=['5413,APOINGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5413-APOINGA")
df_out = api.search(locations=['5414,MANOORA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5414-MANOORA")
df_out = api.search(locations=['5415,MINTARO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5415-MINTARO")
df_out = api.search(locations=['5416,FARRELL FLAT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5416-FARRELL FLAT")
df_out = api.search(locations=['5417,BALAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5417-BALAH")
df_out = api.search(locations=['5418,COLLINSVILLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5418-COLLINSVILLE")
df_out = api.search(locations=['5419,CANOWIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5419-CANOWIE")
df_out = api.search(locations=['5420,CANOWIE BELT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5420-CANOWIE BELT")
df_out = api.search(locations=['5421,FRANKLYN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5421-FRANKLYN")
df_out = api.search(locations=['5422,CAVENAGH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5422-CAVENAGH")
df_out = api.search(locations=['5431,AMYTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5431-AMYTON")
df_out = api.search(locations=['5432,BARATTA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5432-BARATTA")
df_out = api.search(locations=['5433,BRUCE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5433-BRUCE")
df_out = api.search(locations=['5434,BARNDIOOTA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5434-BARNDIOOTA")
df_out = api.search(locations=['5440,ABMINGA STATION'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5440-ABMINGA STATION")
df_out = api.search(locations=['5451,AUBURN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5451-AUBURN")
df_out = api.search(locations=['5452,LEASINGHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5452-LEASINGHAM")
df_out = api.search(locations=['5453,ARMAGH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5453-ARMAGH")
df_out = api.search(locations=['5454,ANDREWS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5454-ANDREWS")
df_out = api.search(locations=['5455,HILLTOWN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5455-HILLTOWN")
df_out = api.search(locations=['5460,BARABBA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5460-BARABBA")
df_out = api.search(locations=['5461,BALAKLAVA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5461-BALAKLAVA")
df_out = api.search(locations=['5462,BLYTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5462-BLYTH")
df_out = api.search(locations=['5464,ANAMA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5464-ANAMA")
df_out = api.search(locations=['5470,YACKA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5470-YACKA")
df_out = api.search(locations=['5471,GULNARE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5471-GULNARE")
df_out = api.search(locations=['5472,GEORGETOWN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5472-GEORGETOWN")
df_out = api.search(locations=['5473,GLADSTONE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5473-GLADSTONE")
df_out = api.search(locations=['5480,APPILA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5480-APPILA")
df_out = api.search(locations=['5481,BANGOR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5481-BANGOR")
df_out = api.search(locations=['5482,BOOLEROO CENTRE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5482-BOOLEROO CENTRE")
df_out = api.search(locations=['5483,MELROSE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5483-MELROSE")
df_out = api.search(locations=['5485,WILMINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5485-WILMINGTON")
df_out = api.search(locations=['5490,CALTOWIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5490-CALTOWIE")
df_out = api.search(locations=['5491,BELALIE EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5491-BELALIE EAST")
df_out = api.search(locations=['5493,YONGALA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5493-YONGALA")
df_out = api.search(locations=['5495,BAROOTA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5495-BAROOTA")
df_out = api.search(locations=['5501,AVON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5501-AVON")
df_out = api.search(locations=['5502,FISCHER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5502-FISCHER")
df_out = api.search(locations=['5510,LOCHIEL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5510-LOCHIEL")
df_out = api.search(locations=['5520,BARUNGA GAP'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5520-BARUNGA GAP")
df_out = api.search(locations=['5521,REDHILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5521-REDHILL")
df_out = api.search(locations=['5522,FISHERMAN BAY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5522-FISHERMAN BAY")
df_out = api.search(locations=['5523,BEETALOO VALLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5523-BEETALOO VALLEY")
df_out = api.search(locations=['5540,BUNGAMA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5540-BUNGAMA")
df_out = api.search(locations=['5550,BEAUFORT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5550-BEAUFORT")
df_out = api.search(locations=['5552,KAINTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5552-KAINTON")
df_out = api.search(locations=['5554,BOORS PLAIN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5554-BOORS PLAIN")
df_out = api.search(locations=['5555,ALFORD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5555-ALFORD")
df_out = api.search(locations=['5556,NORTH BEACH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5556-NORTH BEACH")
df_out = api.search(locations=['5558,AGERY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5558-AGERY")
df_out = api.search(locations=['5560,BUTE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5560-BUTE")
df_out = api.search(locations=['5570,CLINTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5570-CLINTON")
df_out = api.search(locations=['5571,ARDROSSAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5571-ARDROSSAN")
df_out = api.search(locations=['5572,ARTHURTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5572-ARTHURTON")
df_out = api.search(locations=['5573,BALGOWAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5573-BALGOWAN")
df_out = api.search(locations=['5575,BLUFF BEACH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5575-BLUFF BEACH")
df_out = api.search(locations=['5576,HONITON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5576-HONITON")
df_out = api.search(locations=['5577,COUCH BEACH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5577-COUCH BEACH")
df_out = api.search(locations=['5580,CURRAMULKA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5580-CURRAMULKA")
df_out = api.search(locations=['5581,PORT VINCENT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5581-PORT VINCENT")
df_out = api.search(locations=['5582,PORT GILES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5582-PORT GILES")
df_out = api.search(locations=['5583,COOBOWIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5583-COOBOWIE")
df_out = api.search(locations=['5600,IRON BARON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5600-IRON BARON")
df_out = api.search(locations=['5601,BACKY POINT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5601-BACKY POINT")
df_out = api.search(locations=['5602,COWELL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5602-COWELL")
df_out = api.search(locations=['5603,ARNO BAY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5603-ARNO BAY")
df_out = api.search(locations=['5604,PORT NEILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5604-PORT NEILL")
df_out = api.search(locations=['5605,BUTLER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5605-BUTLER")
df_out = api.search(locations=['5606,KIRTON POINT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5606-KIRTON POINT")
df_out = api.search(locations=['5607,BOSTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5607-BOSTON")
df_out = api.search(locations=['5608,MULLAQUANA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5608-MULLAQUANA")
df_out = api.search(locations=['5609,COWLEDS LANDING'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5609-COWLEDS LANDING")
df_out = api.search(locations=['5611,COOYERDOO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5611-COOYERDOO")
df_out = api.search(locations=['5630,EDILILLIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5630-EDILILLIE")
df_out = api.search(locations=['5631,COCKALEECHIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5631-COCKALEECHIE")
df_out = api.search(locations=['5632,KAPINNIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5632-KAPINNIE")
df_out = api.search(locations=['5633,BOONERDO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5633-BOONERDO")
df_out = api.search(locations=['5640,CAMPOONA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5640-CAMPOONA")
df_out = api.search(locations=['5641,BARNA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5641-BARNA")
df_out = api.search(locations=['5642,DARKE PEAK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5642-DARKE PEAK")
df_out = api.search(locations=['5650,COOTRA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5650-COOTRA")
df_out = api.search(locations=['5651,KYANCUTTA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5651-KYANCUTTA")
df_out = api.search(locations=['5652,PANEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5652-PANEY")
df_out = api.search(locations=['5654,COCATA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5654-COCATA")
df_out = api.search(locations=['5655,BOCKELBERG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5655-BOCKELBERG")
df_out = api.search(locations=['5660,CHILPENUNDA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5660-CHILPENUNDA")
df_out = api.search(locations=['5661,KOOLGERA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5661-KOOLGERA")
df_out = api.search(locations=['5670,BRAMFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5670-BRAMFIELD")
df_out = api.search(locations=['5671,BAIRD BAY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5671-BAIRD BAY")
df_out = api.search(locations=['5680,CARAWA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5680-CARAWA")
df_out = api.search(locations=['5690,BOOKABIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5690-BOOKABIE")
df_out = api.search(locations=['5700,BLANCHE HARBOR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5700-BLANCHE HARBOR")
df_out = api.search(locations=['5701,ARKAROOLA VILLAGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5701-ARKAROOLA VILLAGE")
df_out = api.search(locations=['5710,COOK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5710-COOK")
df_out = api.search(locations=['5713,EMEROO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5713-EMEROO")
df_out = api.search(locations=['5715,CARRIEWERLOO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5715-CARRIEWERLOO")
df_out = api.search(locations=['5717,HILTABA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5717-HILTABA")
df_out = api.search(locations=['5719,BON BON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5719-BON BON")
df_out = api.search(locations=['5720,ARCOONA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5720-ARCOONA")
df_out = api.search(locations=['5722,ANDAMOOKA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5722-ANDAMOOKA")
df_out = api.search(locations=['5723,ALLANDALE STATION'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5723-ALLANDALE STATION")
df_out = api.search(locations=['5724,MARLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5724-MARLA")
df_out = api.search(locations=['5725,OLYMPIC DAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5725-OLYMPIC DAM")
df_out = api.search(locations=['5730,ALPANA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5730-ALPANA")
df_out = api.search(locations=['5731,BOLLARDS LAGOON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5731-BOLLARDS LAGOON")
df_out = api.search(locations=['5732,ANGEPENA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5732-ANGEPENA")
df_out = api.search(locations=['5733,ALTON DOWNS STATION'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5733-ALTON DOWNS STATION")
df_out = api.search(locations=['5734,CROWN POINT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5734-CROWN POINT")
df_out = api.search(locations=['5950,ADELAIDE AIRPORT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished rent:5950-ADELAIDE AIRPORT")

DF_ALL1 = DF_ALL.reset_index()
DF_ALL2 = DF_ALL1.drop(columns=['id','index','images','images_floorplans','listers'])
DF_ALL_UNIQ = DF_ALL2.drop_duplicates()

DF_ALL.to_pickle("/Users/joezhou/Downloads/Realestate/R_ALL_SA.pkl")
