# %%
# The aim of this script is to download all rental property data and all available property from realestate website.
# the looping method doesn't work, hence the long winded version

# %%
# pip install -e git+https://github.com/tomquirk/realestate-com-au-api.git#egg=realestate_com_au_api

from realestate_com_au import RealestateComAu
api = RealestateComAu()

# Get property listings
# listings = api.search(locations=["seventeen seventy, qld 4677"], channel="buy", keywords=["tenant"], exclude_keywords=["pool"])

# %%
# https://www.matthewproctor.com/australian_postcodes
# df_postcode = pd.read_excel (r'/Users/joezhou/Downloads/Realestate/australian_postcodes.xlsx', sheet_name='Sheet1')

# sample test suburb
# df_postcode_subset = df_postcode.loc[(df_postcode['Locality']=='LIDCOMBE') & (df_postcode['Postcode']==2141) ]

# df_postcode_subset["VAR_Find"] = '["'+df_postcode_subset['Postcode'].apply(str)+","+df_postcode_subset['Locality']+'"]'
# list_postcode = list(df_postcode_subset['VAR_Find'].dropna())

# %%
import pandas as pd

# try a loop approach by suburb
#note: code below doesn't work for some reason, it returns an arbitary list of values

DF_RENT = pd.DataFrame()
DF_ALL = pd.DataFrame()

def DWN_INF(Find_Text):    
    global DF_RENT
    try:
        df_imp_rent = api.search(locations=Find_Text, channel="rent")
        df_imp_rent = pd.DataFrame(df_imp_rent)
        
        from datetime import datetime as dt
        dte = dt.now().strftime('%Y%m%d')
        fname = "/Users/joezhou/Downloads/loop_test{}.xlsx".format(dte)
        df_imp_rent.to_excel(fname)

        df_imp_all = api.search(locations=Find_Text)
        df_imp_all = pd.DataFrame(df_imp_all)

        DF_RENT = DF_RENT.append(df_imp_rent, ignore_index=True) 
        DF_ALL = DF_ALL.append(df_imp_all, ignore_index=True) 

        print("found for:",Find_Text)

    except Exception:
        print("Error with:",Find_Text)
        pass    
    return()

# Download all
# for Find_Var in list_postcode:
#    DWN_INF(Find_Var)

# %%
# VIC - rental
DF_RENT = pd.DataFrame()

df_out = api.search(locations=['3000,MELBOURNE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3000-MELBOURNE")
df_out = api.search(locations=['3002,EAST MELBOURNE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3002-EAST MELBOURNE")
df_out = api.search(locations=['3003,WEST MELBOURNE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3003-WEST MELBOURNE")
df_out = api.search(locations=['3004,MELBOURNE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3004-MELBOURNE")
df_out = api.search(locations=['3005,WORLD TRADE CENTRE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3005-WORLD TRADE CENTRE")
df_out = api.search(locations=['3006,SOUTH WHARF'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3006-SOUTH WHARF")
df_out = api.search(locations=['3008,DOCKLANDS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3008-DOCKLANDS")
df_out = api.search(locations=['3010,UNIVERSITY OF MELBOURNE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3010-UNIVERSITY OF MELBOURNE")
df_out = api.search(locations=['3011,FOOTSCRAY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3011-FOOTSCRAY")
df_out = api.search(locations=['3012,BROOKLYN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3012-BROOKLYN")
df_out = api.search(locations=['3013,YARRAVILLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3013-YARRAVILLE")
df_out = api.search(locations=['3015,NEWPORT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3015-NEWPORT")
df_out = api.search(locations=['3016,WILLIAMSTOWN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3016-WILLIAMSTOWN")
df_out = api.search(locations=['3018,ALTONA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3018-ALTONA")
df_out = api.search(locations=['3019,BRAYBROOK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3019-BRAYBROOK")
df_out = api.search(locations=['3020,ALBION'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3020-ALBION")
df_out = api.search(locations=['3021,ALBANVALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3021-ALBANVALE")
df_out = api.search(locations=['3022,ARDEER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3022-ARDEER")
df_out = api.search(locations=['3023,BURNSIDE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3023-BURNSIDE")
df_out = api.search(locations=['3024,FIELDSTONE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3024-FIELDSTONE")
df_out = api.search(locations=['3025,ALTONA EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3025-ALTONA EAST")
df_out = api.search(locations=['3026,DERRIMUT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3026-DERRIMUT")
df_out = api.search(locations=['3027,LAVERTON RAAF'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3027-LAVERTON RAAF")
df_out = api.search(locations=['3028,ALTONA MEADOWS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3028-ALTONA MEADOWS")
df_out = api.search(locations=['3029,HOPPERS CROSSING'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3029-HOPPERS CROSSING")
df_out = api.search(locations=['3030,CHARTWELL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3030-CHARTWELL")
df_out = api.search(locations=['3031,FLEMINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3031-FLEMINGTON")
df_out = api.search(locations=['3032,ASCOT VALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3032-ASCOT VALE")
df_out = api.search(locations=['3033,KEILOR EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3033-KEILOR EAST")
df_out = api.search(locations=['3034,AVONDALE HEIGHTS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3034-AVONDALE HEIGHTS")
df_out = api.search(locations=['3036,KEILOR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3036-KEILOR")
df_out = api.search(locations=['3037,CALDER PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3037-CALDER PARK")
df_out = api.search(locations=['3038,KEILOR DOWNS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3038-KEILOR DOWNS")
df_out = api.search(locations=['3039,MOONEE PONDS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3039-MOONEE PONDS")
df_out = api.search(locations=['3040,ABERFELDIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3040-ABERFELDIE")
df_out = api.search(locations=['3041,ESSENDON FIELDS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3041-ESSENDON FIELDS")
df_out = api.search(locations=['3042,AIRPORT WEST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3042-AIRPORT WEST")
df_out = api.search(locations=['3043,GLADSTONE PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3043-GLADSTONE PARK")
df_out = api.search(locations=['3044,PASCOE VALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3044-PASCOE VALE")
df_out = api.search(locations=['3045,MELBOURNE AIRPORT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3045-MELBOURNE AIRPORT")
df_out = api.search(locations=['3046,GLENROY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3046-GLENROY")
df_out = api.search(locations=['3047,BROADMEADOWS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3047-BROADMEADOWS")
df_out = api.search(locations=['3048,COOLAROO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3048-COOLAROO")
df_out = api.search(locations=['3049,ATTWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3049-ATTWOOD")
df_out = api.search(locations=['3050,ROYAL MELBOURNE HOSPITAL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3050-ROYAL MELBOURNE HOSPITAL")
df_out = api.search(locations=['3051,HOTHAM HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3051-HOTHAM HILL")
df_out = api.search(locations=['3052,MELBOURNE UNIVERSITY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3052-MELBOURNE UNIVERSITY")
df_out = api.search(locations=['3053,CARLTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3053-CARLTON")
df_out = api.search(locations=['3054,CARLTON NORTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3054-CARLTON NORTH")
df_out = api.search(locations=['3055,BRUNSWICK SOUTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3055-BRUNSWICK SOUTH")
df_out = api.search(locations=['3056,BRUNSWICK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3056-BRUNSWICK")
df_out = api.search(locations=['3057,BRUNSWICK EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3057-BRUNSWICK EAST")
df_out = api.search(locations=['3058,BATMAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3058-BATMAN")
df_out = api.search(locations=['3059,GREENVALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3059-GREENVALE")
df_out = api.search(locations=['3060,FAWKNER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3060-FAWKNER")
df_out = api.search(locations=['3061,CAMPBELLFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3061-CAMPBELLFIELD")
df_out = api.search(locations=['3062,SOMERTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3062-SOMERTON")
df_out = api.search(locations=['3063,OAKLANDS JUNCTION'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3063-OAKLANDS JUNCTION")
df_out = api.search(locations=['3064,CRAIGIEBURN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3064-CRAIGIEBURN")
df_out = api.search(locations=['3065,FITZROY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3065-FITZROY")
df_out = api.search(locations=['3066,COLLINGWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3066-COLLINGWOOD")
df_out = api.search(locations=['3067,ABBOTSFORD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3067-ABBOTSFORD")
df_out = api.search(locations=['3068,CLIFTON HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3068-CLIFTON HILL")
df_out = api.search(locations=['3070,NORTHCOTE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3070-NORTHCOTE")
df_out = api.search(locations=['3071,THORNBURY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3071-THORNBURY")
df_out = api.search(locations=['3072,GILBERTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3072-GILBERTON")
df_out = api.search(locations=['3073,KEON PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3073-KEON PARK")
df_out = api.search(locations=['3074,THOMASTOWN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3074-THOMASTOWN")
df_out = api.search(locations=['3075,LALOR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3075-LALOR")
df_out = api.search(locations=['3076,EPPING'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3076-EPPING")
df_out = api.search(locations=['3078,ALPHINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3078-ALPHINGTON")
df_out = api.search(locations=['3079,IVANHOE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3079-IVANHOE")
df_out = api.search(locations=['3081,BELLFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3081-BELLFIELD")
df_out = api.search(locations=['3082,MILL PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3082-MILL PARK")
df_out = api.search(locations=['3083,BUNDOORA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3083-BUNDOORA")
df_out = api.search(locations=['3084,BANYULE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3084-BANYULE")
df_out = api.search(locations=['3085,MACLEOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3085-MACLEOD")
df_out = api.search(locations=['3086,LA TROBE UNIVERSITY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3086-LA TROBE UNIVERSITY")
df_out = api.search(locations=['3087,WATSONIA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3087-WATSONIA")
df_out = api.search(locations=['3088,BRIAR HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3088-BRIAR HILL")
df_out = api.search(locations=['3089,DIAMOND CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3089-DIAMOND CREEK")
df_out = api.search(locations=['3090,PLENTY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3090-PLENTY")
df_out = api.search(locations=['3091,YARRAMBAT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3091-YARRAMBAT")
df_out = api.search(locations=['3093,LOWER PLENTY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3093-LOWER PLENTY")
df_out = api.search(locations=['3094,MONTMORENCY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3094-MONTMORENCY")
df_out = api.search(locations=['3095,ELTHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3095-ELTHAM")
df_out = api.search(locations=['3096,WATTLE GLEN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3096-WATTLE GLEN")
df_out = api.search(locations=['3097,BEND OF ISLANDS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3097-BEND OF ISLANDS")
df_out = api.search(locations=['3099,ARTHURS CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3099-ARTHURS CREEK")
df_out = api.search(locations=['3101,COTHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3101-COTHAM")
df_out = api.search(locations=['3102,KEW EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3102-KEW EAST")
df_out = api.search(locations=['3103,BALWYN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3103-BALWYN")
df_out = api.search(locations=['3104,BALWYN NORTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3104-BALWYN NORTH")
df_out = api.search(locations=['3105,BULLEEN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3105-BULLEEN")
df_out = api.search(locations=['3106,TEMPLESTOWE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3106-TEMPLESTOWE")
df_out = api.search(locations=['3107,TEMPLESTOWE LOWER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3107-TEMPLESTOWE LOWER")
df_out = api.search(locations=['3108,DONCASTER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3108-DONCASTER")
df_out = api.search(locations=['3109,DONCASTER EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3109-DONCASTER EAST")
df_out = api.search(locations=['3111,DONVALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3111-DONVALE")
df_out = api.search(locations=['3113,NORTH WARRANDYTE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3113-NORTH WARRANDYTE")
df_out = api.search(locations=['3114,PARK ORCHARDS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3114-PARK ORCHARDS")
df_out = api.search(locations=['3115,WONGA PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3115-WONGA PARK")
df_out = api.search(locations=['3116,CHIRNSIDE PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3116-CHIRNSIDE PARK")
df_out = api.search(locations=['3121,BURNLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3121-BURNLEY")
df_out = api.search(locations=['3122,AUBURN SOUTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3122-AUBURN SOUTH")
df_out = api.search(locations=['3123,AUBURN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3123-AUBURN")
df_out = api.search(locations=['3124,CAMBERWELL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3124-CAMBERWELL")
df_out = api.search(locations=['3125,BENNETTSWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3125-BENNETTSWOOD")
df_out = api.search(locations=['3126,CAMBERWELL EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3126-CAMBERWELL EAST")
df_out = api.search(locations=['3127,MONT ALBERT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3127-MONT ALBERT")
df_out = api.search(locations=['3128,BOX HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3128-BOX HILL")
df_out = api.search(locations=['3129,BOX HILL NORTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3129-BOX HILL NORTH")
df_out = api.search(locations=['3130,BLACKBURN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3130-BLACKBURN")
df_out = api.search(locations=['3131,BRENTFORD SQUARE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3131-BRENTFORD SQUARE")
df_out = api.search(locations=['3132,MITCHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3132-MITCHAM")
df_out = api.search(locations=['3133,VERMONT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3133-VERMONT")
df_out = api.search(locations=['3134,HEATHWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3134-HEATHWOOD")
df_out = api.search(locations=['3135,BEDFORD ROAD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3135-BEDFORD ROAD")
df_out = api.search(locations=['3136,CROYDON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3136-CROYDON")
df_out = api.search(locations=['3137,KILSYTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3137-KILSYTH")
df_out = api.search(locations=['3138,MOOROOLBARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3138-MOOROOLBARK")
df_out = api.search(locations=['3139,BEENAK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3139-BEENAK")
df_out = api.search(locations=['3140,LILYDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3140-LILYDALE")
df_out = api.search(locations=['3141,CHAPEL STREET NORTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3141-CHAPEL STREET NORTH")
df_out = api.search(locations=['3142,HAWKSBURN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3142-HAWKSBURN")
df_out = api.search(locations=['3143,ARMADALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3143-ARMADALE")
df_out = api.search(locations=['3144,KOOYONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3144-KOOYONG")
df_out = api.search(locations=['3145,CAULFIELD EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3145-CAULFIELD EAST")
df_out = api.search(locations=['3146,GLEN IRIS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3146-GLEN IRIS")
df_out = api.search(locations=['3147,ASHBURTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3147-ASHBURTON")
df_out = api.search(locations=['3148,CHADSTONE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3148-CHADSTONE")
df_out = api.search(locations=['3149,MOUNT WAVERLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3149-MOUNT WAVERLEY")
df_out = api.search(locations=['3150,BRANDON PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3150-BRANDON PARK")
df_out = api.search(locations=['3151,BURWOOD EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3151-BURWOOD EAST")
df_out = api.search(locations=['3152,KNOX CITY CENTRE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3152-KNOX CITY CENTRE")
df_out = api.search(locations=['3153,BAYSWATER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3153-BAYSWATER")
df_out = api.search(locations=['3154,THE BASIN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3154-THE BASIN")
df_out = api.search(locations=['3155,BORONIA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3155-BORONIA")
df_out = api.search(locations=['3156,FERNTREE GULLY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3156-FERNTREE GULLY")
df_out = api.search(locations=['3158,UPWEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3158-UPWEY")
df_out = api.search(locations=['3159,MENZIES CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3159-MENZIES CREEK")
df_out = api.search(locations=['3160,BELGRAVE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3160-BELGRAVE")
df_out = api.search(locations=['3161,CAULFIELD JUNCTION'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3161-CAULFIELD JUNCTION")
df_out = api.search(locations=['3162,CAULFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3162-CAULFIELD")
df_out = api.search(locations=['3163,BOORAN ROAD PO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3163-BOORAN ROAD PO")
df_out = api.search(locations=['3165,BENTLEIGH EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3165-BENTLEIGH EAST")
df_out = api.search(locations=['3166,HUGHESDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3166-HUGHESDALE")
df_out = api.search(locations=['3167,OAKLEIGH SOUTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3167-OAKLEIGH SOUTH")
df_out = api.search(locations=['3168,CLAYTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3168-CLAYTON")
df_out = api.search(locations=['3169,CLARINDA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3169-CLARINDA")
df_out = api.search(locations=['3170,MULGRAVE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3170-MULGRAVE")
df_out = api.search(locations=['3171,SANDOWN VILLAGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3171-SANDOWN VILLAGE")
df_out = api.search(locations=['3172,DINGLEY VILLAGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3172-DINGLEY VILLAGE")
df_out = api.search(locations=['3173,KEYSBOROUGH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3173-KEYSBOROUGH")
df_out = api.search(locations=['3174,NOBLE PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3174-NOBLE PARK")
df_out = api.search(locations=['3175,BANGHOLME'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3175-BANGHOLME")
df_out = api.search(locations=['3177,DOVETON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3177-DOVETON")
df_out = api.search(locations=['3178,ROWVILLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3178-ROWVILLE")
df_out = api.search(locations=['3179,SCORESBY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3179-SCORESBY")
df_out = api.search(locations=['3180,KNOXFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3180-KNOXFIELD")
df_out = api.search(locations=['3181,PRAHRAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3181-PRAHRAN")
df_out = api.search(locations=['3182,ST KILDA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3182-ST KILDA")
df_out = api.search(locations=['3183,BALACLAVA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3183-BALACLAVA")
df_out = api.search(locations=['3184,BRIGHTON ROAD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3184-BRIGHTON ROAD")
df_out = api.search(locations=['3185,ELSTERNWICK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3185-ELSTERNWICK")
df_out = api.search(locations=['3186,BRIGHTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3186-BRIGHTON")
df_out = api.search(locations=['3187,BRIGHTON EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3187-BRIGHTON EAST")
df_out = api.search(locations=['3188,HAMPTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3188-HAMPTON")
df_out = api.search(locations=['3189,MOORABBIN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3189-MOORABBIN")
df_out = api.search(locations=['3190,HIGHETT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3190-HIGHETT")
df_out = api.search(locations=['3191,SANDRINGHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3191-SANDRINGHAM")
df_out = api.search(locations=['3192,CHELTENHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3192-CHELTENHAM")
df_out = api.search(locations=['3193,BEAUMARIS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3193-BEAUMARIS")
df_out = api.search(locations=['3194,MENTONE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3194-MENTONE")
df_out = api.search(locations=['3195,ASPENDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3195-ASPENDALE")
df_out = api.search(locations=['3196,BONBEACH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3196-BONBEACH")
df_out = api.search(locations=['3197,CARRUM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3197-CARRUM")
df_out = api.search(locations=['3198,BELVEDERE PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3198-BELVEDERE PARK")
df_out = api.search(locations=['3199,FRANKSTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3199-FRANKSTON")
df_out = api.search(locations=['3200,FRANKSTON NORTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3200-FRANKSTON NORTH")
df_out = api.search(locations=['3201,CARRUM DOWNS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3201-CARRUM DOWNS")
df_out = api.search(locations=['3202,HEATHERTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3202-HEATHERTON")
df_out = api.search(locations=['3204,BENTLEIGH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3204-BENTLEIGH")
df_out = api.search(locations=['3205,SOUTH MELBOURNE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3205-SOUTH MELBOURNE")
df_out = api.search(locations=['3206,ALBERT PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3206-ALBERT PARK")
df_out = api.search(locations=['3207,GARDEN CITY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3207-GARDEN CITY")
df_out = api.search(locations=['3211,LITTLE RIVER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3211-LITTLE RIVER")
df_out = api.search(locations=['3212,AVALON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3212-AVALON")
df_out = api.search(locations=['3213,ANAKIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3213-ANAKIE")
df_out = api.search(locations=['3214,CORIO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3214-CORIO")
df_out = api.search(locations=['3215,BELL PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3215-BELL PARK")
df_out = api.search(locations=['3216,BELMONT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3216-BELMONT")
df_out = api.search(locations=['3217,ARMSTRONG CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3217-ARMSTRONG CREEK")
df_out = api.search(locations=['3218,FYANSFORD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3218-FYANSFORD")
df_out = api.search(locations=['3219,BREAKWATER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3219-BREAKWATER")
df_out = api.search(locations=['3220,BAREENA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3220-BAREENA")
df_out = api.search(locations=['3221,ANAKIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3221-ANAKIE")
df_out = api.search(locations=['3222,CLIFTON SPRINGS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3222-CLIFTON SPRINGS")
df_out = api.search(locations=['3223,BELLARINE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3223-BELLARINE")
df_out = api.search(locations=['3224,LEOPOLD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3224-LEOPOLD")
df_out = api.search(locations=['3225,POINT LONSDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3225-POINT LONSDALE")
df_out = api.search(locations=['3226,OCEAN GROVE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3226-OCEAN GROVE")
df_out = api.search(locations=['3227,BARWON HEADS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3227-BARWON HEADS")
df_out = api.search(locations=['3228,BELLBRAE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3228-BELLBRAE")
df_out = api.search(locations=['3230,ANGLESEA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3230-ANGLESEA")
df_out = api.search(locations=['3231,AIREYS INLET'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3231-AIREYS INLET")
df_out = api.search(locations=['3232,BIG HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3232-BIG HILL")
df_out = api.search(locations=['3233,APOLLO BAY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3233-APOLLO BAY")
df_out = api.search(locations=['3234,GREY RIVER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3234-GREY RIVER")
df_out = api.search(locations=['3235,BENWERRIN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3235-BENWERRIN")
df_out = api.search(locations=['3236,FORREST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3236-FORREST")
df_out = api.search(locations=['3237,AIRE VALLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3237-AIRE VALLEY")
df_out = api.search(locations=['3238,GLENAIRE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3238-GLENAIRE")
df_out = api.search(locations=['3239,CARLISLE RIVER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3239-CARLISLE RIVER")
df_out = api.search(locations=['3240,BUCKLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3240-BUCKLEY")
df_out = api.search(locations=['3241,BAMBRA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3241-BAMBRA")
df_out = api.search(locations=['3242,BIRREGURRA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3242-BIRREGURRA")
df_out = api.search(locations=['3243,BARWON DOWNS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3243-BARWON DOWNS")
df_out = api.search(locations=['3249,ALVIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3249-ALVIE")
df_out = api.search(locations=['3250,COLAC'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3250-COLAC")
df_out = api.search(locations=['3251,BEEAC'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3251-BEEAC")
df_out = api.search(locations=['3254,COROROOKE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3254-COROROOKE")
df_out = api.search(locations=['3260,BOOKAAR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3260-BOOKAAR")
df_out = api.search(locations=['3264,TERANG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3264-TERANG")
df_out = api.search(locations=['3265,BOORCAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3265-BOORCAN")
df_out = api.search(locations=['3266,BULLAHARRE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3266-BULLAHARRE")
df_out = api.search(locations=['3267,SCOTTS CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3267-SCOTTS CREEK")
df_out = api.search(locations=['3268,AYRFORD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3268-AYRFORD")
df_out = api.search(locations=['3269,PORT CAMPBELL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3269-PORT CAMPBELL")
df_out = api.search(locations=['3270,PETERBOROUGH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3270-PETERBOROUGH")
df_out = api.search(locations=['3271,DARLINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3271-DARLINGTON")
df_out = api.search(locations=['3272,MORTLAKE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3272-MORTLAKE")
df_out = api.search(locations=['3273,HEXHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3273-HEXHAM")
df_out = api.search(locations=['3274,CARAMUT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3274-CARAMUT")
df_out = api.search(locations=['3275,MAILER FLAT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3275-MAILER FLAT")
df_out = api.search(locations=['3276,MINJAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3276-MINJAH")
df_out = api.search(locations=['3277,ALLANSFORD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3277-ALLANSFORD")
df_out = api.search(locations=['3278,PURNIM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3278-PURNIM")
df_out = api.search(locations=['3279,BALLANGEICH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3279-BALLANGEICH")
df_out = api.search(locations=['3280,DENNINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3280-DENNINGTON")
df_out = api.search(locations=['3281,BUSHFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3281-BUSHFIELD")
df_out = api.search(locations=['3282,ILLOWA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3282-ILLOWA")
df_out = api.search(locations=['3283,CROSSLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3283-CROSSLEY")
df_out = api.search(locations=['3284,ORFORD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3284-ORFORD")
df_out = api.search(locations=['3285,CODRINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3285-CODRINGTON")
df_out = api.search(locations=['3286,CONDAH SWAMP'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3286-CONDAH SWAMP")
df_out = api.search(locations=['3287,HAWKESDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3287-HAWKESDALE")
df_out = api.search(locations=['3289,GAZETTE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3289-GAZETTE")
df_out = api.search(locations=['3292,NELSON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3292-NELSON")
df_out = api.search(locations=['3293,GLENTHOMPSON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3293-GLENTHOMPSON")
df_out = api.search(locations=['3294,DUNKELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3294-DUNKELD")
df_out = api.search(locations=['3300,BYADUK NORTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3300-BYADUK NORTH")
df_out = api.search(locations=['3301,BOCHARA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3301-BOCHARA")
df_out = api.search(locations=['3302,BRANXHOLME'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3302-BRANXHOLME")
df_out = api.search(locations=['3303,BREAKAWAY CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3303-BREAKAWAY CREEK")
df_out = api.search(locations=['3304,BESSIEBELLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3304-BESSIEBELLE")
df_out = api.search(locations=['3305,ALLESTREE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3305-ALLESTREE")
df_out = api.search(locations=['3309,DIGBY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3309-DIGBY")
df_out = api.search(locations=['3310,MERINO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3310-MERINO")
df_out = api.search(locations=['3311,CASTERTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3311-CASTERTON")
df_out = api.search(locations=['3312,BAHGALLAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3312-BAHGALLAH")
df_out = api.search(locations=['3314,BULART'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3314-BULART")
df_out = api.search(locations=['3315,BRIT BRIT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3315-BRIT BRIT")
df_out = api.search(locations=['3317,HARROW'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3317-HARROW")
df_out = api.search(locations=['3318,CHARAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3318-CHARAM")
df_out = api.search(locations=['3319,APSLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3319-APSLEY")
df_out = api.search(locations=['3321,HESSE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3321-HESSE")
df_out = api.search(locations=['3322,CRESSY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3322-CRESSY")
df_out = api.search(locations=['3323,BERRYBANK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3323-BERRYBANK")
df_out = api.search(locations=['3324,LISMORE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3324-LISMORE")
df_out = api.search(locations=['3325,DERRINALLUM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3325-DERRINALLUM")
df_out = api.search(locations=['3328,TEESDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3328-TEESDALE")
df_out = api.search(locations=['3329,BARUNAH PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3329-BARUNAH PARK")
df_out = api.search(locations=['3330,ROKEWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3330-ROKEWOOD")
df_out = api.search(locations=['3331,BANNOCKBURN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3331-BANNOCKBURN")
df_out = api.search(locations=['3332,LETHBRIDGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3332-LETHBRIDGE")
df_out = api.search(locations=['3333,BAMGANIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3333-BAMGANIE")
df_out = api.search(locations=['3334,BUNGAL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3334-BUNGAL")
df_out = api.search(locations=['3335,BONNIE BROOK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3335-BONNIE BROOK")
df_out = api.search(locations=['3336,AINTREE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3336-AINTREE")
df_out = api.search(locations=['3337,HARKNESS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3337-HARKNESS")
df_out = api.search(locations=['3338,BROOKFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3338-BROOKFIELD")
df_out = api.search(locations=['3340,BACCHUS MARSH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3340-BACCHUS MARSH")
df_out = api.search(locations=['3341,DALES CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3341-DALES CREEK")
df_out = api.search(locations=['3342,BALLAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3342-BALLAN")
df_out = api.search(locations=['3345,GORDON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3345-GORDON")
df_out = api.search(locations=['3350,ALFREDTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3350-ALFREDTON")
df_out = api.search(locations=['3351,BERRINGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3351-BERRINGA")
df_out = api.search(locations=['3352,ADDINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3352-ADDINGTON")
df_out = api.search(locations=['3355,LAKE GARDENS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3355-LAKE GARDENS")
df_out = api.search(locations=['3356,BONSHAW'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3356-BONSHAW")
df_out = api.search(locations=['3357,BUNINYONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3357-BUNINYONG")
df_out = api.search(locations=['3358,WINTER VALLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3358-WINTER VALLEY")
df_out = api.search(locations=['3360,HAPPY VALLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3360-HAPPY VALLEY")
df_out = api.search(locations=['3361,BRADVALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3361-BRADVALE")
df_out = api.search(locations=['3363,CRESWICK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3363-CRESWICK")
df_out = api.search(locations=['3364,ALLENDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3364-ALLENDALE")
df_out = api.search(locations=['3370,CLUNES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3370-CLUNES")
df_out = api.search(locations=['3371,AMHERST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3371-AMHERST")
df_out = api.search(locations=['3373,BEAUFORT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3373-BEAUFORT")
df_out = api.search(locations=['3375,BALLYROGAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3375-BALLYROGAN")
df_out = api.search(locations=['3377,AMPHITHEATRE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3377-AMPHITHEATRE")
df_out = api.search(locations=['3378,TATYOON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3378-TATYOON")
df_out = api.search(locations=['3379,BERRAMBOOL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3379-BERRAMBOOL")
df_out = api.search(locations=['3380,BELLELLEN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3380-BELLELLEN")
df_out = api.search(locations=['3381,BARKLY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3381-BARKLY")
df_out = api.search(locations=['3384,BARKLY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3384-BARKLY")
df_out = api.search(locations=['3385,DADSWELLS BRIDGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3385-DADSWELLS BRIDGE")
df_out = api.search(locations=['3387,BOLANGUM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3387-BOLANGUM")
df_out = api.search(locations=['3388,BANYENA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3388-BANYENA")
df_out = api.search(locations=['3390,KEWELL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3390-KEWELL")
df_out = api.search(locations=['3391,BRIM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3391-BRIM")
df_out = api.search(locations=['3392,BOOLITE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3392-BOOLITE")
df_out = api.search(locations=['3393,AILSA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3393-AILSA")
df_out = api.search(locations=['3395,BEULAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3395-BEULAH")
df_out = api.search(locations=['3396,HOPETOUN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3396-HOPETOUN")
df_out = api.search(locations=['3400,BRIMPAEN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3400-BRIMPAEN")
df_out = api.search(locations=['3401,BLACKHEATH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3401-BLACKHEATH")
df_out = api.search(locations=['3407,BALMORAL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3407-BALMORAL")
df_out = api.search(locations=['3409,ARAPILES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3409-ARAPILES")
df_out = api.search(locations=['3412,GOROKE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3412-GOROKE")
df_out = api.search(locations=['3413,MINIMAY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3413-MINIMAY")
df_out = api.search(locations=['3414,ANTWERP'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3414-ANTWERP")
df_out = api.search(locations=['3415,MIRAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3415-MIRAM")
df_out = api.search(locations=['3418,BROUGHTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3418-BROUGHTON")
df_out = api.search(locations=['3419,KANIVA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3419-KANIVA")
df_out = api.search(locations=['3420,LILLIMUR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3420-LILLIMUR")
df_out = api.search(locations=['3423,JEPARIT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3423-JEPARIT")
df_out = api.search(locations=['3424,ALBACUTYA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3424-ALBACUTYA")
df_out = api.search(locations=['3427,DIGGERS REST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3427-DIGGERS REST")
df_out = api.search(locations=['3428,BULLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3428-BULLA")
df_out = api.search(locations=['3429,SUNBURY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3429-SUNBURY")
df_out = api.search(locations=['3430,CLARKEFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3430-CLARKEFIELD")
df_out = api.search(locations=['3431,RIDDELLS CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3431-RIDDELLS CREEK")
df_out = api.search(locations=['3432,BOLINDA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3432-BOLINDA")
df_out = api.search(locations=['3434,CHEROKEE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3434-CHEROKEE")
df_out = api.search(locations=['3435,BENLOCH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3435-BENLOCH")
df_out = api.search(locations=['3437,BULLENGAROOK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3437-BULLENGAROOK")
df_out = api.search(locations=['3438,NEW GISBORNE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3438-NEW GISBORNE")
df_out = api.search(locations=['3440,MACEDON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3440-MACEDON")
df_out = api.search(locations=['3441,MOUNT MACEDON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3441-MOUNT MACEDON")
df_out = api.search(locations=['3442,ASHBOURNE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3442-ASHBOURNE")
df_out = api.search(locations=['3444,BARFOLD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3444-BARFOLD")
df_out = api.search(locations=['3446,DRUMMOND NORTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3446-DRUMMOND NORTH")
df_out = api.search(locations=['3447,TARADALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3447-TARADALE")
df_out = api.search(locations=['3448,ELPHINSTONE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3448-ELPHINSTONE")
df_out = api.search(locations=['3450,CASTLEMAINE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3450-CASTLEMAINE")
df_out = api.search(locations=['3451,BARKERS CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3451-BARKERS CREEK")
df_out = api.search(locations=['3453,HARCOURT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3453-HARCOURT")
df_out = api.search(locations=['3458,BARRYS REEF'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3458-BARRYS REEF")
df_out = api.search(locations=['3460,BASALT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3460-BASALT")
df_out = api.search(locations=['3461,BULLARTO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3461-BULLARTO")
df_out = api.search(locations=['3462,GREEN GULLY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3462-GREEN GULLY")
df_out = api.search(locations=['3463,BARINGHUP'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3463-BARINGHUP")
df_out = api.search(locations=['3464,CARISBROOK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3464-CARISBROOK")
df_out = api.search(locations=['3465,ADELAIDE LEAD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3465-ADELAIDE LEAD")
df_out = api.search(locations=['3467,AVOCA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3467-AVOCA")
df_out = api.search(locations=['3468,AMPHITHEATRE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3468-AMPHITHEATRE")
df_out = api.search(locations=['3469,ELMHURST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3469-ELMHURST")
df_out = api.search(locations=['3472,BET BET'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3472-BET BET")
df_out = api.search(locations=['3475,ARCHDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3475-ARCHDALE")
df_out = api.search(locations=['3478,AVON PLAINS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3478-AVON PLAINS")
df_out = api.search(locations=['3480,AREEGRA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3480-AREEGRA")
df_out = api.search(locations=['3482,MASSEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3482-MASSEY")
df_out = api.search(locations=['3483,BALLAPUR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3483-BALLAPUR")
df_out = api.search(locations=['3485,BANYAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3485-BANYAN")
df_out = api.search(locations=['3487,LASCELLES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3487-LASCELLES")
df_out = api.search(locations=['3488,SPEED'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3488-SPEED")
df_out = api.search(locations=['3489,TEMPY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3489-TEMPY")
df_out = api.search(locations=['3490,BIG DESERT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3490-BIG DESERT")
df_out = api.search(locations=['3491,PATCHEWOLLOCK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3491-PATCHEWOLLOCK")
df_out = api.search(locations=['3494,CARWARP'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3494-CARWARP")
df_out = api.search(locations=['3496,CARDROSS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3496-CARDROSS")
df_out = api.search(locations=['3498,IRYMPLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3498-IRYMPLE")
df_out = api.search(locations=['3500,MILDURA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3500-MILDURA")
df_out = api.search(locations=['3501,HATTAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3501-HATTAH")
df_out = api.search(locations=['3505,BIRDWOODTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3505-BIRDWOODTON")
df_out = api.search(locations=['3506,COWANGIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3506-COWANGIE")
df_out = api.search(locations=['3507,WALPEUP'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3507-WALPEUP")
df_out = api.search(locations=['3509,LINGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3509-LINGA")
df_out = api.search(locations=['3512,CARINA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3512-CARINA")
df_out = api.search(locations=['3515,MARONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3515-MARONG")
df_out = api.search(locations=['3516,BRIDGEWATER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3516-BRIDGEWATER")
df_out = api.search(locations=['3517,BEARS LAGOON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3517-BEARS LAGOON")
df_out = api.search(locations=['3518,BERRIMAL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3518-BERRIMAL")
df_out = api.search(locations=['3520,KINYPANIAL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3520-KINYPANIAL")
df_out = api.search(locations=['3521,PYALONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3521-PYALONG")
df_out = api.search(locations=['3522,EMU FLAT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3522-EMU FLAT")
df_out = api.search(locations=['3523,ARGYLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3523-ARGYLE")
df_out = api.search(locations=['3525,BARRAKEE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3525-BARRAKEE")
df_out = api.search(locations=['3527,BUNGULUKE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3527-BUNGULUKE")
df_out = api.search(locations=['3529,KALPIENUNG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3529-KALPIENUNG")
df_out = api.search(locations=['3530,CULGOA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3530-CULGOA")
df_out = api.search(locations=['3531,BERRIWILLOCK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3531-BERRIWILLOCK")
df_out = api.search(locations=['3533,BIMBOURIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3533-BIMBOURIE")
df_out = api.search(locations=['3537,BARRAPORT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3537-BARRAPORT")
df_out = api.search(locations=['3540,CANNIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3540-CANNIE")
df_out = api.search(locations=['3542,COKUM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3542-COKUM")
df_out = api.search(locations=['3544,CHINANGIN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3544-CHINANGIN")
df_out = api.search(locations=['3546,BOLTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3546-BOLTON")
df_out = api.search(locations=['3549,ANNUELLO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3549-ANNUELLO")
df_out = api.search(locations=['3550,BENDIGO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3550-BENDIGO")
df_out = api.search(locations=['3551,ARNOLD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3551-ARNOLD")
df_out = api.search(locations=['3555,BIG HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3555-BIG HILL")
df_out = api.search(locations=['3556,CALIFORNIA GULLY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3556-CALIFORNIA GULLY")
df_out = api.search(locations=['3557,BARNADOWN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3557-BARNADOWN")
df_out = api.search(locations=['3558,BURNEWANG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3558-BURNEWANG")
df_out = api.search(locations=['3559,AVONMORE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3559-AVONMORE")
df_out = api.search(locations=['3561,BALLENDELLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3561-BALLENDELLA")
df_out = api.search(locations=['3562,TORRUMBARRY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3562-TORRUMBARRY")
df_out = api.search(locations=['3563,LOCKINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3563-LOCKINGTON")
df_out = api.search(locations=['3564,BAMAWM EXTENSION'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3564-BAMAWM EXTENSION")
df_out = api.search(locations=['3565,KOTTA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3565-KOTTA")
df_out = api.search(locations=['3566,GUNBOWER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3566-GUNBOWER")
df_out = api.search(locations=['3567,HORFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3567-HORFIELD")
df_out = api.search(locations=['3568,BURKES BRIDGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3568-BURKES BRIDGE")
df_out = api.search(locations=['3570,AUCHMORE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3570-AUCHMORE")
df_out = api.search(locations=['3571,DINGEE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3571-DINGEE")
df_out = api.search(locations=['3572,MILLOO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3572-MILLOO")
df_out = api.search(locations=['3573,CALIVIL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3573-CALIVIL")
df_out = api.search(locations=['3575,BALD ROCK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3575-BALD ROCK")
df_out = api.search(locations=['3576,DURHAM OX'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3576-DURHAM OX")
df_out = api.search(locations=['3579,APPIN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3579-APPIN")
df_out = api.search(locations=['3580,KOONDROOK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3580-KOONDROOK")
df_out = api.search(locations=['3581,BEAUCHAMP'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3581-BEAUCHAMP")
df_out = api.search(locations=['3583,TRESCO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3583-TRESCO")
df_out = api.search(locations=['3584,LAKE BOGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3584-LAKE BOGA")
df_out = api.search(locations=['3585,CASTLE DONNINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3585-CASTLE DONNINGTON")
df_out = api.search(locations=['3586,BULGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3586-BULGA")
df_out = api.search(locations=['3588,WOORINEN SOUTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3588-WOORINEN SOUTH")
df_out = api.search(locations=['3589,WOORINEN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3589-WOORINEN")
df_out = api.search(locations=['3590,BEVERFORD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3590-BEVERFORD")
df_out = api.search(locations=['3591,VINIFERA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3591-VINIFERA")
df_out = api.search(locations=['3594,NYAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3594-NYAH")
df_out = api.search(locations=['3595,NYAH WEST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3595-NYAH WEST")
df_out = api.search(locations=['3596,MIRALIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3596-MIRALIE")
df_out = api.search(locations=['3597,KENLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3597-KENLEY")
df_out = api.search(locations=['3599,BOUNDARY BEND'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3599-BOUNDARY BEND")
df_out = api.search(locations=['3607,TABILK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3607-TABILK")
df_out = api.search(locations=['3608,BAILIESTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3608-BAILIESTON")
df_out = api.search(locations=['3610,DHURRINGILE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3610-DHURRINGILE")
df_out = api.search(locations=['3612,MOORA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3612-MOORA")
df_out = api.search(locations=['3614,TOOLAMBA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3614-TOOLAMBA")
df_out = api.search(locations=['3616,COOMA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3616-COOMA")
df_out = api.search(locations=['3617,BYRNESIDE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3617-BYRNESIDE")
df_out = api.search(locations=['3618,MERRIGUM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3618-MERRIGUM")
df_out = api.search(locations=['3620,KYABRAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3620-KYABRAM")
df_out = api.search(locations=['3621,KOYUGA SOUTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3621-KOYUGA SOUTH")
df_out = api.search(locations=['3622,CORNELIA CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3622-CORNELIA CREEK")
df_out = api.search(locations=['3623,CARAG CARAG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3623-CARAG CARAG")
df_out = api.search(locations=['3624,GIRGARRE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3624-GIRGARRE")
df_out = api.search(locations=['3629,ARDMONA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3629-ARDMONA")
df_out = api.search(locations=['3630,BENARCH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3630-BENARCH")
df_out = api.search(locations=['3631,ARCADIA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3631-ARCADIA")
df_out = api.search(locations=['3633,CONGUPNA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3633-CONGUPNA")
df_out = api.search(locations=['3634,BUNBARTHA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3634-BUNBARTHA")
df_out = api.search(locations=['3635,KAARIMBA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3635-KAARIMBA")
df_out = api.search(locations=['3636,DRUMANURE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3636-DRUMANURE")
df_out = api.search(locations=['3637,WAAIA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3637-WAAIA")
df_out = api.search(locations=['3638,KOTUPNA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3638-KOTUPNA")
df_out = api.search(locations=['3639,BARMAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3639-BARMAH")
df_out = api.search(locations=['3640,KATUNGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3640-KATUNGA")
df_out = api.search(locations=['3641,BEARII'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3641-BEARII")
df_out = api.search(locations=['3644,BAROOGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3644-BAROOGA")
df_out = api.search(locations=['3646,DOOKIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3646-DOOKIE")
df_out = api.search(locations=['3649,KATAMATITE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3649-KATAMATITE")
df_out = api.search(locations=['3658,BROADFORD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3658-BROADFORD")
df_out = api.search(locations=['3659,SUGARLOAF CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3659-SUGARLOAF CREEK")
df_out = api.search(locations=['3660,CAVEAT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3660-CAVEAT")
df_out = api.search(locations=['3662,PUCKAPUNYAL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3662-PUCKAPUNYAL")
df_out = api.search(locations=['3663,MANGALORE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3663-MANGALORE")
df_out = api.search(locations=['3664,AVENEL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3664-AVENEL")
df_out = api.search(locations=['3665,LOCKSLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3665-LOCKSLEY")
df_out = api.search(locations=['3666,BALMATTUM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3666-BALMATTUM")
df_out = api.search(locations=['3669,BOHO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3669-BOHO")
df_out = api.search(locations=['3670,BADDAGINNIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3670-BADDAGINNIE")
df_out = api.search(locations=['3672,BENALLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3672-BENALLA")
df_out = api.search(locations=['3673,BENALLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3673-BENALLA")
df_out = api.search(locations=['3675,BOWEYA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3675-BOWEYA")
df_out = api.search(locations=['3677,APPIN PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3677-APPIN PARK")
df_out = api.search(locations=['3678,BOBINAWARRAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3678-BOBINAWARRAH")
df_out = api.search(locations=['3682,BORALMA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3682-BORALMA")
df_out = api.search(locations=['3683,CHILTERN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3683-CHILTERN")
df_out = api.search(locations=['3685,BOORHAMAN NORTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3685-BOORHAMAN NORTH")
df_out = api.search(locations=['3687,CARLYLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3687-CARLYLE")
df_out = api.search(locations=['3688,BARNAWARTHA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3688-BARNAWARTHA")
df_out = api.search(locations=['3690,WEST WODONGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3690-WEST WODONGA")
df_out = api.search(locations=['3691,ALLANS FLAT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3691-ALLANS FLAT")
df_out = api.search(locations=['3694,BANDIANA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3694-BANDIANA")
df_out = api.search(locations=['3695,CHARLEROI'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3695-CHARLEROI")
df_out = api.search(locations=['3697,TAWONGA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3697-TAWONGA")
df_out = api.search(locations=['3699,BOGONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3699-BOGONG")
df_out = api.search(locations=['3700,BULLIOH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3700-BULLIOH")
df_out = api.search(locations=['3701,DARTMOUTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3701-DARTMOUTH")
df_out = api.search(locations=['3704,KOETONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3704-KOETONG")
df_out = api.search(locations=['3705,CUDGEWA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3705-CUDGEWA")
df_out = api.search(locations=['3707,BIGGARA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3707-BIGGARA")
df_out = api.search(locations=['3708,TINTALDRA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3708-TINTALDRA")
df_out = api.search(locations=['3709,BURROWYE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3709-BURROWYE")
df_out = api.search(locations=['3711,BUXTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3711-BUXTON")
df_out = api.search(locations=['3712,RUBICON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3712-RUBICON")
df_out = api.search(locations=['3713,EILDON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3713-EILDON")
df_out = api.search(locations=['3714,ACHERON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3714-ACHERON")
df_out = api.search(locations=['3715,ANCONA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3715-ANCONA")
df_out = api.search(locations=['3717,FLOWERDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3717-FLOWERDALE")
df_out = api.search(locations=['3718,MOLESWORTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3718-MOLESWORTH")
df_out = api.search(locations=['3719,GOBUR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3719-GOBUR")
df_out = api.search(locations=['3720,BONNIE DOON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3720-BONNIE DOON")
df_out = api.search(locations=['3722,BARWITE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3722-BARWITE")
df_out = api.search(locations=['3723,ARCHERTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3723-ARCHERTON")
df_out = api.search(locations=['3725,BOXWOOD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3725-BOXWOOD")
df_out = api.search(locations=['3726,BUNGEET'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3726-BUNGEET")
df_out = api.search(locations=['3727,ALMONDS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3727-ALMONDS")
df_out = api.search(locations=['3728,BOOMAHNOOMOONAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3728-BOOMAHNOOMOONAH")
df_out = api.search(locations=['3730,BATHUMI'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3730-BATHUMI")
df_out = api.search(locations=['3732,MOYHU'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3732-MOYHU")
df_out = api.search(locations=['3733,WHITFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3733-WHITFIELD")
df_out = api.search(locations=['3735,BOWMANS FOREST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3735-BOWMANS FOREST")
df_out = api.search(locations=['3737,ABBEYARD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3737-ABBEYARD")
df_out = api.search(locations=['3738,OVENS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3738-OVENS")
df_out = api.search(locations=['3739,EUROBIN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3739-EUROBIN")
df_out = api.search(locations=['3740,BUCKLAND'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3740-BUCKLAND")
df_out = api.search(locations=['3741,BRIGHT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3741-BRIGHT")
df_out = api.search(locations=['3744,WANDILIGONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3744-WANDILIGONG")
df_out = api.search(locations=['3746,ELDORADO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3746-ELDORADO")
df_out = api.search(locations=['3747,BAARMUTHA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3747-BAARMUTHA")
df_out = api.search(locations=['3749,BRUARONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3749-BRUARONG")
df_out = api.search(locations=['3750,WOLLERT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3750-WOLLERT")
df_out = api.search(locations=['3751,WOODSTOCK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3751-WOODSTOCK")
df_out = api.search(locations=['3752,MORANG SOUTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3752-MORANG SOUTH")
df_out = api.search(locations=['3753,BEVERIDGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3753-BEVERIDGE")
df_out = api.search(locations=['3754,DOREEN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3754-DOREEN")
df_out = api.search(locations=['3755,YAN YEAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3755-YAN YEAN")
df_out = api.search(locations=['3756,CHINTIN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3756-CHINTIN")
df_out = api.search(locations=['3757,BRUCES CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3757-BRUCES CREEK")
df_out = api.search(locations=['3758,HEATHCOTE JUNCTION'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3758-HEATHCOTE JUNCTION")
df_out = api.search(locations=['3759,PANTON HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3759-PANTON HILL")
df_out = api.search(locations=['3760,SMITHS GULLY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3760-SMITHS GULLY")
df_out = api.search(locations=['3763,KINGLAKE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3763-KINGLAKE")
df_out = api.search(locations=['3764,FORBES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3764-FORBES")
df_out = api.search(locations=['3765,MONTROSE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3765-MONTROSE")
df_out = api.search(locations=['3766,KALORAMA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3766-KALORAMA")
df_out = api.search(locations=['3767,MOUNT DANDENONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3767-MOUNT DANDENONG")
df_out = api.search(locations=['3770,COLDSTREAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3770-COLDSTREAM")
df_out = api.search(locations=['3775,CHRISTMAS HILLS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3775-CHRISTMAS HILLS")
df_out = api.search(locations=['3777,BADGER CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3777-BADGER CREEK")
df_out = api.search(locations=['3778,FERNSHAW'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3778-FERNSHAW")
df_out = api.search(locations=['3779,CAMBARVILLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3779-CAMBARVILLE")
df_out = api.search(locations=['3781,COCKATOO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3781-COCKATOO")
df_out = api.search(locations=['3782,AVONSLEIGH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3782-AVONSLEIGH")
df_out = api.search(locations=['3783,GEMBROOK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3783-GEMBROOK")
df_out = api.search(locations=['3785,TREMONT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3785-TREMONT")
df_out = api.search(locations=['3786,FERNY CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3786-FERNY CREEK")
df_out = api.search(locations=['3787,SASSAFRAS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3787-SASSAFRAS")
df_out = api.search(locations=['3788,OLINDA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3788-OLINDA")
df_out = api.search(locations=['3789,SHERBROOKE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3789-SHERBROOKE")
df_out = api.search(locations=['3791,KALLISTA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3791-KALLISTA")
df_out = api.search(locations=['3792,THE PATCH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3792-THE PATCH")
df_out = api.search(locations=['3793,MONBULK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3793-MONBULK")
df_out = api.search(locations=['3795,SILVAN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3795-SILVAN")
df_out = api.search(locations=['3796,MOUNT EVELYN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3796-MOUNT EVELYN")
df_out = api.search(locations=['3797,GILDEROY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3797-GILDEROY")
df_out = api.search(locations=['3799,BIG PATS CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3799-BIG PATS CREEK")
df_out = api.search(locations=['3800,MONASH UNIVERSITY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3800-MONASH UNIVERSITY")
df_out = api.search(locations=['3802,ENDEAVOUR HILLS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3802-ENDEAVOUR HILLS")
df_out = api.search(locations=['3803,HALLAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3803-HALLAM")
df_out = api.search(locations=['3804,NARRE WARREN EAST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3804-NARRE WARREN EAST")
df_out = api.search(locations=['3805,FOUNTAIN GATE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3805-FOUNTAIN GATE")
df_out = api.search(locations=['3806,BERWICK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3806-BERWICK")
df_out = api.search(locations=['3807,BEACONSFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3807-BEACONSFIELD")
df_out = api.search(locations=['3808,BEACONSFIELD UPPER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3808-BEACONSFIELD UPPER")
df_out = api.search(locations=['3809,OFFICER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3809-OFFICER")
df_out = api.search(locations=['3810,PAKENHAM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3810-PAKENHAM")
df_out = api.search(locations=['3812,MARYKNOLL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3812-MARYKNOLL")
df_out = api.search(locations=['3813,TYNONG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3813-TYNONG")
df_out = api.search(locations=['3814,CORA LYNN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3814-CORA LYNN")
df_out = api.search(locations=['3815,BUNYIP'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3815-BUNYIP")
df_out = api.search(locations=['3816,LABERTOUCHE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3816-LABERTOUCHE")
df_out = api.search(locations=['3818,ATHLONE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3818-ATHLONE")
df_out = api.search(locations=['3820,BONA VISTA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3820-BONA VISTA")
df_out = api.search(locations=['3821,BRANDY CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3821-BRANDY CREEK")
df_out = api.search(locations=['3822,CLOVERLEA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3822-CLOVERLEA")
df_out = api.search(locations=['3823,ALLAMBEE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3823-ALLAMBEE")
df_out = api.search(locations=['3824,CHILDERS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3824-CHILDERS")
df_out = api.search(locations=['3825,ABERFELDY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3825-ABERFELDY")
df_out = api.search(locations=['3831,NEERIM'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3831-NEERIM")
df_out = api.search(locations=['3832,NAYOOK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3832-NAYOOK")
df_out = api.search(locations=['3833,ADA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3833-ADA")
df_out = api.search(locations=['3835,THORPDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3835-THORPDALE")
df_out = api.search(locations=['3840,DRIFFIELD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3840-DRIFFIELD")
df_out = api.search(locations=['3842,CHURCHILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3842-CHURCHILL")
df_out = api.search(locations=['3844,BLACKWARRY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3844-BLACKWARRY")
df_out = api.search(locations=['3847,HIAMDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3847-HIAMDALE")
df_out = api.search(locations=['3850,GIFFARD'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3850-GIFFARD")
df_out = api.search(locations=['3851,AIRLY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3851-AIRLY")
df_out = api.search(locations=['3852,EAST SALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3852-EAST SALE")
df_out = api.search(locations=['3854,GLENGARRY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3854-GLENGARRY")
df_out = api.search(locations=['3856,TOONGABBIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3856-TOONGABBIE")
df_out = api.search(locations=['3857,COWWARR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3857-COWWARR")
df_out = api.search(locations=['3858,ARBUCKLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3858-ARBUCKLE")
df_out = api.search(locations=['3859,MAFFRA WEST UPPER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3859-MAFFRA WEST UPPER")
df_out = api.search(locations=['3860,BOISDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3860-BOISDALE")
df_out = api.search(locations=['3862,BUDGEE BUDGEE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3862-BUDGEE BUDGEE")
df_out = api.search(locations=['3864,FERNBANK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3864-FERNBANK")
df_out = api.search(locations=['3865,LINDENOW'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3865-LINDENOW")
df_out = api.search(locations=['3869,JUMBUK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3869-JUMBUK")
df_out = api.search(locations=['3870,BOOLARRA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3870-BOOLARRA")
df_out = api.search(locations=['3871,ALLAMBEE RESERVE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3871-ALLAMBEE RESERVE")
df_out = api.search(locations=['3873,GORMANDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3873-GORMANDALE")
df_out = api.search(locations=['3874,CARRAJUNG SOUTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3874-CARRAJUNG SOUTH")
df_out = api.search(locations=['3875,BAIRNSDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3875-BAIRNSDALE")
df_out = api.search(locations=['3878,EAGLE POINT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3878-EAGLE POINT")
df_out = api.search(locations=['3880,BOOLE POOLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3880-BOOLE POOLE")
df_out = api.search(locations=['3882,NICHOLSON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3882-NICHOLSON")
df_out = api.search(locations=['3885,BRUMBY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3885-BRUMBY")
df_out = api.search(locations=['3886,NEWMERELLA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3886-NEWMERELLA")
df_out = api.search(locations=['3887,LAKE TYERS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3887-LAKE TYERS")
df_out = api.search(locations=['3888,BENDOC'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3888-BENDOC")
df_out = api.search(locations=['3889,BELL BIRD CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3889-BELL BIRD CREEK")
df_out = api.search(locations=['3890,BULDAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3890-BULDAH")
df_out = api.search(locations=['3891,GENOA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3891-GENOA")
df_out = api.search(locations=['3892,MALLACOOTA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3892-MALLACOOTA")
df_out = api.search(locations=['3893,DOUBLE BRIDGES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3893-DOUBLE BRIDGES")
df_out = api.search(locations=['3895,DOCTORS FLAT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3895-DOCTORS FLAT")
df_out = api.search(locations=['3896,BINDI'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3896-BINDI")
df_out = api.search(locations=['3898,ANGLERS REST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3898-ANGLERS REST")
df_out = api.search(locations=['3900,BENAMBRA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3900-BENAMBRA")
df_out = api.search(locations=['3902,BUMBERRAH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3902-BUMBERRAH")
df_out = api.search(locations=['3903,SWAN REACH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3903-SWAN REACH")
df_out = api.search(locations=['3904,METUNG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3904-METUNG")
df_out = api.search(locations=['3909,KALIMNA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3909-KALIMNA")
df_out = api.search(locations=['3910,LANGWARRIN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3910-LANGWARRIN")
df_out = api.search(locations=['3911,BAXTER'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3911-BAXTER")
df_out = api.search(locations=['3912,PEARCEDALE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3912-PEARCEDALE")
df_out = api.search(locations=['3913,TYABB'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3913-TYABB")
df_out = api.search(locations=['3915,HASTINGS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3915-HASTINGS")
df_out = api.search(locations=['3916,MERRICKS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3916-MERRICKS")
df_out = api.search(locations=['3918,BITTERN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3918-BITTERN")
df_out = api.search(locations=['3919,CRIB POINT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3919-CRIB POINT")
df_out = api.search(locations=['3921,ELIZABETH ISLAND'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3921-ELIZABETH ISLAND")
df_out = api.search(locations=['3922,COWES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3922-COWES")
df_out = api.search(locations=['3923,RHYLL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3923-RHYLL")
df_out = api.search(locations=['3925,CAPE WOOLAMAI'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3925-CAPE WOOLAMAI")
df_out = api.search(locations=['3926,BALNARRING'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3926-BALNARRING")
df_out = api.search(locations=['3927,SOMERS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3927-SOMERS")
df_out = api.search(locations=['3928,MAIN RIDGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3928-MAIN RIDGE")
df_out = api.search(locations=['3929,FLINDERS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3929-FLINDERS")
df_out = api.search(locations=['3930,KUNYUNG'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3930-KUNYUNG")
df_out = api.search(locations=['3931,MORNINGTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3931-MORNINGTON")
df_out = api.search(locations=['3933,MOOROODUC'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3933-MOOROODUC")
df_out = api.search(locations=['3934,MOUNT MARTHA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3934-MOUNT MARTHA")
df_out = api.search(locations=['3936,ARTHURS SEAT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3936-ARTHURS SEAT")
df_out = api.search(locations=['3937,RED HILL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3937-RED HILL")
df_out = api.search(locations=['3938,MCCRAE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3938-MCCRAE")
df_out = api.search(locations=['3939,BONEO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3939-BONEO")
df_out = api.search(locations=['3940,CAPEL SOUND'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3940-CAPEL SOUND")
df_out = api.search(locations=['3941,RYE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3941-RYE")
df_out = api.search(locations=['3942,BLAIRGOWRIE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3942-BLAIRGOWRIE")
df_out = api.search(locations=['3943,SORRENTO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3943-SORRENTO")
df_out = api.search(locations=['3944,PORTSEA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3944-PORTSEA")
df_out = api.search(locations=['3945,BELLVIEW'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3945-BELLVIEW")
df_out = api.search(locations=['3946,BENA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3946-BENA")
df_out = api.search(locations=['3950,KARDELLA SOUTH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3950-KARDELLA SOUTH")
df_out = api.search(locations=['3951,ARAWATA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3951-ARAWATA")
df_out = api.search(locations=['3953,BERRYS CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3953-BERRYS CREEK")
df_out = api.search(locations=['3954,KOONWARRA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3954-KOONWARRA")
df_out = api.search(locations=['3956,DUMBALK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3956-DUMBALK")
df_out = api.search(locations=['3957,GRASSY SPUR'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3957-GRASSY SPUR")
df_out = api.search(locations=['3958,BUFFALO'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3958-BUFFALO")
df_out = api.search(locations=['3959,FISH CREEK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3959-FISH CREEK")
df_out = api.search(locations=['3960,BENNISON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3960-BENNISON")
df_out = api.search(locations=['3962,AGNES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3962-AGNES")
df_out = api.search(locations=['3964,PORT FRANKLIN'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3964-PORT FRANKLIN")
df_out = api.search(locations=['3965,PORT WELSHPOOL'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3965-PORT WELSHPOOL")
df_out = api.search(locations=['3966,BINGINWARRI'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3966-BINGINWARRI")
df_out = api.search(locations=['3967,HEDLEY'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3967-HEDLEY")
df_out = api.search(locations=['3971,ALBERTON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3971-ALBERTON")
df_out = api.search(locations=['3975,LYNBROOK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3975-LYNBROOK")
df_out = api.search(locations=['3976,HAMPTON PARK'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3976-HAMPTON PARK")
df_out = api.search(locations=['3977,BOTANIC RIDGE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3977-BOTANIC RIDGE")
df_out = api.search(locations=['3978,CARDINIA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3978-CARDINIA")
df_out = api.search(locations=['3979,ALMURTA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3979-ALMURTA")
df_out = api.search(locations=['3980,BLIND BIGHT'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3980-BLIND BIGHT")
df_out = api.search(locations=['3981,BAYLES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3981-BAYLES")
df_out = api.search(locations=['3984,ADAMS ESTATE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3984-ADAMS ESTATE")
df_out = api.search(locations=['3987,NYORA'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3987-NYORA")
df_out = api.search(locations=['3988,MOUNTAIN VIEW'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3988-MOUNTAIN VIEW")
df_out = api.search(locations=['3990,GLEN FORBES'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3990-GLEN FORBES")
df_out = api.search(locations=['3991,BASS'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3991-BASS")
df_out = api.search(locations=['3992,BLACKWOOD FOREST'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3992-BLACKWOOD FOREST")
df_out = api.search(locations=['3995,ANDERSON'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3995-ANDERSON")
df_out = api.search(locations=['3996,INVERLOCH'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:3996-INVERLOCH")
df_out = api.search(locations=['9999,NORTH POLE'],channel="rent")
df_out = pd.DataFrame(df_out)
DF_RENT = DF_RENT.append(df_out, ignore_index=True) 
print("finished rent:9999-NORTH POLE")

DF_RENT1 = DF_RENT.reset_index()
DF_RENT2 = DF_RENT1.drop(columns=['id','index','images','images_floorplans','listers'])
DF_RENT_UNIQ = DF_RENT2.drop_duplicates()

DF_RENT_UNIQ.to_pickle("/Users/joezhou/Downloads/Realestate/R_RENT_VIC.pkl")

# %%
# VIC - all
DF_ALL = pd.DataFrame()

df_out = api.search(locations=['3000,MELBOURNE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3000-MELBOURNE")
df_out = api.search(locations=['3002,EAST MELBOURNE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3002-EAST MELBOURNE")
df_out = api.search(locations=['3003,WEST MELBOURNE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3003-WEST MELBOURNE")
df_out = api.search(locations=['3004,MELBOURNE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3004-MELBOURNE")
df_out = api.search(locations=['3005,WORLD TRADE CENTRE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3005-WORLD TRADE CENTRE")
df_out = api.search(locations=['3006,SOUTH WHARF'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3006-SOUTH WHARF")
df_out = api.search(locations=['3008,DOCKLANDS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3008-DOCKLANDS")
df_out = api.search(locations=['3010,UNIVERSITY OF MELBOURNE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3010-UNIVERSITY OF MELBOURNE")
df_out = api.search(locations=['3011,FOOTSCRAY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3011-FOOTSCRAY")
df_out = api.search(locations=['3012,BROOKLYN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3012-BROOKLYN")
df_out = api.search(locations=['3013,YARRAVILLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3013-YARRAVILLE")
df_out = api.search(locations=['3015,NEWPORT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3015-NEWPORT")
df_out = api.search(locations=['3016,WILLIAMSTOWN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3016-WILLIAMSTOWN")
df_out = api.search(locations=['3018,ALTONA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3018-ALTONA")
df_out = api.search(locations=['3019,BRAYBROOK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3019-BRAYBROOK")
df_out = api.search(locations=['3020,ALBION'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3020-ALBION")
df_out = api.search(locations=['3021,ALBANVALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3021-ALBANVALE")
df_out = api.search(locations=['3022,ARDEER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3022-ARDEER")
df_out = api.search(locations=['3023,BURNSIDE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3023-BURNSIDE")
df_out = api.search(locations=['3024,FIELDSTONE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3024-FIELDSTONE")
df_out = api.search(locations=['3025,ALTONA EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3025-ALTONA EAST")
df_out = api.search(locations=['3026,DERRIMUT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3026-DERRIMUT")
df_out = api.search(locations=['3027,LAVERTON RAAF'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3027-LAVERTON RAAF")
df_out = api.search(locations=['3028,ALTONA MEADOWS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3028-ALTONA MEADOWS")
df_out = api.search(locations=['3029,HOPPERS CROSSING'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3029-HOPPERS CROSSING")
df_out = api.search(locations=['3030,CHARTWELL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3030-CHARTWELL")
df_out = api.search(locations=['3031,FLEMINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3031-FLEMINGTON")
df_out = api.search(locations=['3032,ASCOT VALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3032-ASCOT VALE")
df_out = api.search(locations=['3033,KEILOR EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3033-KEILOR EAST")
df_out = api.search(locations=['3034,AVONDALE HEIGHTS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3034-AVONDALE HEIGHTS")
df_out = api.search(locations=['3036,KEILOR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3036-KEILOR")
df_out = api.search(locations=['3037,CALDER PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3037-CALDER PARK")
df_out = api.search(locations=['3038,KEILOR DOWNS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3038-KEILOR DOWNS")
df_out = api.search(locations=['3039,MOONEE PONDS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3039-MOONEE PONDS")
df_out = api.search(locations=['3040,ABERFELDIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3040-ABERFELDIE")
df_out = api.search(locations=['3041,ESSENDON FIELDS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3041-ESSENDON FIELDS")
df_out = api.search(locations=['3042,AIRPORT WEST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3042-AIRPORT WEST")
df_out = api.search(locations=['3043,GLADSTONE PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3043-GLADSTONE PARK")
df_out = api.search(locations=['3044,PASCOE VALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3044-PASCOE VALE")
df_out = api.search(locations=['3045,MELBOURNE AIRPORT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3045-MELBOURNE AIRPORT")
df_out = api.search(locations=['3046,GLENROY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3046-GLENROY")
df_out = api.search(locations=['3047,BROADMEADOWS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3047-BROADMEADOWS")
df_out = api.search(locations=['3048,COOLAROO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3048-COOLAROO")
df_out = api.search(locations=['3049,ATTWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3049-ATTWOOD")
df_out = api.search(locations=['3050,ROYAL MELBOURNE HOSPITAL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3050-ROYAL MELBOURNE HOSPITAL")
df_out = api.search(locations=['3051,HOTHAM HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3051-HOTHAM HILL")
df_out = api.search(locations=['3052,MELBOURNE UNIVERSITY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3052-MELBOURNE UNIVERSITY")
df_out = api.search(locations=['3053,CARLTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3053-CARLTON")
df_out = api.search(locations=['3054,CARLTON NORTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3054-CARLTON NORTH")
df_out = api.search(locations=['3055,BRUNSWICK SOUTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3055-BRUNSWICK SOUTH")
df_out = api.search(locations=['3056,BRUNSWICK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3056-BRUNSWICK")
df_out = api.search(locations=['3057,BRUNSWICK EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3057-BRUNSWICK EAST")
df_out = api.search(locations=['3058,BATMAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3058-BATMAN")
df_out = api.search(locations=['3059,GREENVALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3059-GREENVALE")
df_out = api.search(locations=['3060,FAWKNER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3060-FAWKNER")
df_out = api.search(locations=['3061,CAMPBELLFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3061-CAMPBELLFIELD")
df_out = api.search(locations=['3062,SOMERTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3062-SOMERTON")
df_out = api.search(locations=['3063,OAKLANDS JUNCTION'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3063-OAKLANDS JUNCTION")
df_out = api.search(locations=['3064,CRAIGIEBURN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3064-CRAIGIEBURN")
df_out = api.search(locations=['3065,FITZROY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3065-FITZROY")
df_out = api.search(locations=['3066,COLLINGWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3066-COLLINGWOOD")
df_out = api.search(locations=['3067,ABBOTSFORD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3067-ABBOTSFORD")
df_out = api.search(locations=['3068,CLIFTON HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3068-CLIFTON HILL")
df_out = api.search(locations=['3070,NORTHCOTE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3070-NORTHCOTE")
df_out = api.search(locations=['3071,THORNBURY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3071-THORNBURY")
df_out = api.search(locations=['3072,GILBERTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3072-GILBERTON")
df_out = api.search(locations=['3073,KEON PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3073-KEON PARK")
df_out = api.search(locations=['3074,THOMASTOWN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3074-THOMASTOWN")
df_out = api.search(locations=['3075,LALOR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3075-LALOR")
df_out = api.search(locations=['3076,EPPING'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3076-EPPING")
df_out = api.search(locations=['3078,ALPHINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3078-ALPHINGTON")
df_out = api.search(locations=['3079,IVANHOE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3079-IVANHOE")
df_out = api.search(locations=['3081,BELLFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3081-BELLFIELD")
df_out = api.search(locations=['3082,MILL PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3082-MILL PARK")
df_out = api.search(locations=['3083,BUNDOORA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3083-BUNDOORA")
df_out = api.search(locations=['3084,BANYULE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3084-BANYULE")
df_out = api.search(locations=['3085,MACLEOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3085-MACLEOD")
df_out = api.search(locations=['3086,LA TROBE UNIVERSITY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3086-LA TROBE UNIVERSITY")
df_out = api.search(locations=['3087,WATSONIA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3087-WATSONIA")
df_out = api.search(locations=['3088,BRIAR HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3088-BRIAR HILL")
df_out = api.search(locations=['3089,DIAMOND CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3089-DIAMOND CREEK")
df_out = api.search(locations=['3090,PLENTY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3090-PLENTY")
df_out = api.search(locations=['3091,YARRAMBAT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3091-YARRAMBAT")
df_out = api.search(locations=['3093,LOWER PLENTY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3093-LOWER PLENTY")
df_out = api.search(locations=['3094,MONTMORENCY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3094-MONTMORENCY")
df_out = api.search(locations=['3095,ELTHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3095-ELTHAM")
df_out = api.search(locations=['3096,WATTLE GLEN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3096-WATTLE GLEN")
df_out = api.search(locations=['3097,BEND OF ISLANDS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3097-BEND OF ISLANDS")
df_out = api.search(locations=['3099,ARTHURS CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3099-ARTHURS CREEK")
df_out = api.search(locations=['3101,COTHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3101-COTHAM")
df_out = api.search(locations=['3102,KEW EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3102-KEW EAST")
df_out = api.search(locations=['3103,BALWYN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3103-BALWYN")
df_out = api.search(locations=['3104,BALWYN NORTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3104-BALWYN NORTH")
df_out = api.search(locations=['3105,BULLEEN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3105-BULLEEN")
df_out = api.search(locations=['3106,TEMPLESTOWE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3106-TEMPLESTOWE")
df_out = api.search(locations=['3107,TEMPLESTOWE LOWER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3107-TEMPLESTOWE LOWER")
df_out = api.search(locations=['3108,DONCASTER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3108-DONCASTER")
df_out = api.search(locations=['3109,DONCASTER EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3109-DONCASTER EAST")
df_out = api.search(locations=['3111,DONVALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3111-DONVALE")
df_out = api.search(locations=['3113,NORTH WARRANDYTE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3113-NORTH WARRANDYTE")
df_out = api.search(locations=['3114,PARK ORCHARDS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3114-PARK ORCHARDS")
df_out = api.search(locations=['3115,WONGA PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3115-WONGA PARK")
df_out = api.search(locations=['3116,CHIRNSIDE PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3116-CHIRNSIDE PARK")
df_out = api.search(locations=['3121,BURNLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3121-BURNLEY")
df_out = api.search(locations=['3122,AUBURN SOUTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3122-AUBURN SOUTH")
df_out = api.search(locations=['3123,AUBURN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3123-AUBURN")
df_out = api.search(locations=['3124,CAMBERWELL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3124-CAMBERWELL")
df_out = api.search(locations=['3125,BENNETTSWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3125-BENNETTSWOOD")
df_out = api.search(locations=['3126,CAMBERWELL EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3126-CAMBERWELL EAST")
df_out = api.search(locations=['3127,MONT ALBERT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3127-MONT ALBERT")
df_out = api.search(locations=['3128,BOX HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3128-BOX HILL")
df_out = api.search(locations=['3129,BOX HILL NORTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3129-BOX HILL NORTH")
df_out = api.search(locations=['3130,BLACKBURN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3130-BLACKBURN")
df_out = api.search(locations=['3131,BRENTFORD SQUARE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3131-BRENTFORD SQUARE")
df_out = api.search(locations=['3132,MITCHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3132-MITCHAM")
df_out = api.search(locations=['3133,VERMONT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3133-VERMONT")
df_out = api.search(locations=['3134,HEATHWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3134-HEATHWOOD")
df_out = api.search(locations=['3135,BEDFORD ROAD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3135-BEDFORD ROAD")
df_out = api.search(locations=['3136,CROYDON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3136-CROYDON")
df_out = api.search(locations=['3137,KILSYTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3137-KILSYTH")
df_out = api.search(locations=['3138,MOOROOLBARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3138-MOOROOLBARK")
df_out = api.search(locations=['3139,BEENAK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3139-BEENAK")
df_out = api.search(locations=['3140,LILYDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3140-LILYDALE")
df_out = api.search(locations=['3141,CHAPEL STREET NORTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3141-CHAPEL STREET NORTH")
df_out = api.search(locations=['3142,HAWKSBURN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3142-HAWKSBURN")
df_out = api.search(locations=['3143,ARMADALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3143-ARMADALE")
df_out = api.search(locations=['3144,KOOYONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3144-KOOYONG")
df_out = api.search(locations=['3145,CAULFIELD EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3145-CAULFIELD EAST")
df_out = api.search(locations=['3146,GLEN IRIS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3146-GLEN IRIS")
df_out = api.search(locations=['3147,ASHBURTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3147-ASHBURTON")
df_out = api.search(locations=['3148,CHADSTONE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3148-CHADSTONE")
df_out = api.search(locations=['3149,MOUNT WAVERLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3149-MOUNT WAVERLEY")
df_out = api.search(locations=['3150,BRANDON PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3150-BRANDON PARK")
df_out = api.search(locations=['3151,BURWOOD EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3151-BURWOOD EAST")
df_out = api.search(locations=['3152,KNOX CITY CENTRE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3152-KNOX CITY CENTRE")
df_out = api.search(locations=['3153,BAYSWATER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3153-BAYSWATER")
df_out = api.search(locations=['3154,THE BASIN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3154-THE BASIN")
df_out = api.search(locations=['3155,BORONIA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3155-BORONIA")
df_out = api.search(locations=['3156,FERNTREE GULLY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3156-FERNTREE GULLY")
df_out = api.search(locations=['3158,UPWEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3158-UPWEY")
df_out = api.search(locations=['3159,MENZIES CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3159-MENZIES CREEK")
df_out = api.search(locations=['3160,BELGRAVE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3160-BELGRAVE")
df_out = api.search(locations=['3161,CAULFIELD JUNCTION'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3161-CAULFIELD JUNCTION")
df_out = api.search(locations=['3162,CAULFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3162-CAULFIELD")
df_out = api.search(locations=['3163,BOORAN ROAD PO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3163-BOORAN ROAD PO")
df_out = api.search(locations=['3165,BENTLEIGH EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3165-BENTLEIGH EAST")
df_out = api.search(locations=['3166,HUGHESDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3166-HUGHESDALE")
df_out = api.search(locations=['3167,OAKLEIGH SOUTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3167-OAKLEIGH SOUTH")
df_out = api.search(locations=['3168,CLAYTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3168-CLAYTON")
df_out = api.search(locations=['3169,CLARINDA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3169-CLARINDA")
df_out = api.search(locations=['3170,MULGRAVE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3170-MULGRAVE")
df_out = api.search(locations=['3171,SANDOWN VILLAGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3171-SANDOWN VILLAGE")
df_out = api.search(locations=['3172,DINGLEY VILLAGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3172-DINGLEY VILLAGE")
df_out = api.search(locations=['3173,KEYSBOROUGH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3173-KEYSBOROUGH")
df_out = api.search(locations=['3174,NOBLE PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3174-NOBLE PARK")
df_out = api.search(locations=['3175,BANGHOLME'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3175-BANGHOLME")
df_out = api.search(locations=['3177,DOVETON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3177-DOVETON")
df_out = api.search(locations=['3178,ROWVILLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3178-ROWVILLE")
df_out = api.search(locations=['3179,SCORESBY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3179-SCORESBY")
df_out = api.search(locations=['3180,KNOXFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3180-KNOXFIELD")
df_out = api.search(locations=['3181,PRAHRAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3181-PRAHRAN")
df_out = api.search(locations=['3182,ST KILDA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3182-ST KILDA")
df_out = api.search(locations=['3183,BALACLAVA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3183-BALACLAVA")
df_out = api.search(locations=['3184,BRIGHTON ROAD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3184-BRIGHTON ROAD")
df_out = api.search(locations=['3185,ELSTERNWICK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3185-ELSTERNWICK")
df_out = api.search(locations=['3186,BRIGHTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3186-BRIGHTON")
df_out = api.search(locations=['3187,BRIGHTON EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3187-BRIGHTON EAST")
df_out = api.search(locations=['3188,HAMPTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3188-HAMPTON")
df_out = api.search(locations=['3189,MOORABBIN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3189-MOORABBIN")
df_out = api.search(locations=['3190,HIGHETT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3190-HIGHETT")
df_out = api.search(locations=['3191,SANDRINGHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3191-SANDRINGHAM")
df_out = api.search(locations=['3192,CHELTENHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3192-CHELTENHAM")
df_out = api.search(locations=['3193,BEAUMARIS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3193-BEAUMARIS")
df_out = api.search(locations=['3194,MENTONE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3194-MENTONE")
df_out = api.search(locations=['3195,ASPENDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3195-ASPENDALE")
df_out = api.search(locations=['3196,BONBEACH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3196-BONBEACH")
df_out = api.search(locations=['3197,CARRUM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3197-CARRUM")
df_out = api.search(locations=['3198,BELVEDERE PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3198-BELVEDERE PARK")
df_out = api.search(locations=['3199,FRANKSTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3199-FRANKSTON")
df_out = api.search(locations=['3200,FRANKSTON NORTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3200-FRANKSTON NORTH")
df_out = api.search(locations=['3201,CARRUM DOWNS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3201-CARRUM DOWNS")
df_out = api.search(locations=['3202,HEATHERTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3202-HEATHERTON")
df_out = api.search(locations=['3204,BENTLEIGH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3204-BENTLEIGH")
df_out = api.search(locations=['3205,SOUTH MELBOURNE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3205-SOUTH MELBOURNE")
df_out = api.search(locations=['3206,ALBERT PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3206-ALBERT PARK")
df_out = api.search(locations=['3207,GARDEN CITY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3207-GARDEN CITY")
df_out = api.search(locations=['3211,LITTLE RIVER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3211-LITTLE RIVER")
df_out = api.search(locations=['3212,AVALON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3212-AVALON")
df_out = api.search(locations=['3213,ANAKIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3213-ANAKIE")
df_out = api.search(locations=['3214,CORIO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3214-CORIO")
df_out = api.search(locations=['3215,BELL PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3215-BELL PARK")
df_out = api.search(locations=['3216,BELMONT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3216-BELMONT")
df_out = api.search(locations=['3217,ARMSTRONG CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3217-ARMSTRONG CREEK")
df_out = api.search(locations=['3218,FYANSFORD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3218-FYANSFORD")
df_out = api.search(locations=['3219,BREAKWATER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3219-BREAKWATER")
df_out = api.search(locations=['3220,BAREENA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3220-BAREENA")
df_out = api.search(locations=['3221,ANAKIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3221-ANAKIE")
df_out = api.search(locations=['3222,CLIFTON SPRINGS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3222-CLIFTON SPRINGS")
df_out = api.search(locations=['3223,BELLARINE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3223-BELLARINE")
df_out = api.search(locations=['3224,LEOPOLD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3224-LEOPOLD")
df_out = api.search(locations=['3225,POINT LONSDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3225-POINT LONSDALE")
df_out = api.search(locations=['3226,OCEAN GROVE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3226-OCEAN GROVE")
df_out = api.search(locations=['3227,BARWON HEADS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3227-BARWON HEADS")
df_out = api.search(locations=['3228,BELLBRAE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3228-BELLBRAE")
df_out = api.search(locations=['3230,ANGLESEA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3230-ANGLESEA")
df_out = api.search(locations=['3231,AIREYS INLET'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3231-AIREYS INLET")
df_out = api.search(locations=['3232,BIG HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3232-BIG HILL")
df_out = api.search(locations=['3233,APOLLO BAY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3233-APOLLO BAY")
df_out = api.search(locations=['3234,GREY RIVER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3234-GREY RIVER")
df_out = api.search(locations=['3235,BENWERRIN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3235-BENWERRIN")
df_out = api.search(locations=['3236,FORREST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3236-FORREST")
df_out = api.search(locations=['3237,AIRE VALLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3237-AIRE VALLEY")
df_out = api.search(locations=['3238,GLENAIRE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3238-GLENAIRE")
df_out = api.search(locations=['3239,CARLISLE RIVER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3239-CARLISLE RIVER")
df_out = api.search(locations=['3240,BUCKLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3240-BUCKLEY")
df_out = api.search(locations=['3241,BAMBRA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3241-BAMBRA")
df_out = api.search(locations=['3242,BIRREGURRA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3242-BIRREGURRA")
df_out = api.search(locations=['3243,BARWON DOWNS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3243-BARWON DOWNS")
df_out = api.search(locations=['3249,ALVIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3249-ALVIE")
df_out = api.search(locations=['3250,COLAC'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3250-COLAC")
df_out = api.search(locations=['3251,BEEAC'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3251-BEEAC")
df_out = api.search(locations=['3254,COROROOKE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3254-COROROOKE")
df_out = api.search(locations=['3260,BOOKAAR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3260-BOOKAAR")
df_out = api.search(locations=['3264,TERANG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3264-TERANG")
df_out = api.search(locations=['3265,BOORCAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3265-BOORCAN")
df_out = api.search(locations=['3266,BULLAHARRE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3266-BULLAHARRE")
df_out = api.search(locations=['3267,SCOTTS CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3267-SCOTTS CREEK")
df_out = api.search(locations=['3268,AYRFORD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3268-AYRFORD")
df_out = api.search(locations=['3269,PORT CAMPBELL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3269-PORT CAMPBELL")
df_out = api.search(locations=['3270,PETERBOROUGH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3270-PETERBOROUGH")
df_out = api.search(locations=['3271,DARLINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3271-DARLINGTON")
df_out = api.search(locations=['3272,MORTLAKE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3272-MORTLAKE")
df_out = api.search(locations=['3273,HEXHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3273-HEXHAM")
df_out = api.search(locations=['3274,CARAMUT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3274-CARAMUT")
df_out = api.search(locations=['3275,MAILER FLAT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3275-MAILER FLAT")
df_out = api.search(locations=['3276,MINJAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3276-MINJAH")
df_out = api.search(locations=['3277,ALLANSFORD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3277-ALLANSFORD")
df_out = api.search(locations=['3278,PURNIM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3278-PURNIM")
df_out = api.search(locations=['3279,BALLANGEICH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3279-BALLANGEICH")
df_out = api.search(locations=['3280,DENNINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3280-DENNINGTON")
df_out = api.search(locations=['3281,BUSHFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3281-BUSHFIELD")
df_out = api.search(locations=['3282,ILLOWA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3282-ILLOWA")
df_out = api.search(locations=['3283,CROSSLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3283-CROSSLEY")
df_out = api.search(locations=['3284,ORFORD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3284-ORFORD")
df_out = api.search(locations=['3285,CODRINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3285-CODRINGTON")
df_out = api.search(locations=['3286,CONDAH SWAMP'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3286-CONDAH SWAMP")
df_out = api.search(locations=['3287,HAWKESDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3287-HAWKESDALE")
df_out = api.search(locations=['3289,GAZETTE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3289-GAZETTE")
df_out = api.search(locations=['3292,NELSON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3292-NELSON")
df_out = api.search(locations=['3293,GLENTHOMPSON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3293-GLENTHOMPSON")
df_out = api.search(locations=['3294,DUNKELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3294-DUNKELD")
df_out = api.search(locations=['3300,BYADUK NORTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3300-BYADUK NORTH")
df_out = api.search(locations=['3301,BOCHARA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3301-BOCHARA")
df_out = api.search(locations=['3302,BRANXHOLME'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3302-BRANXHOLME")
df_out = api.search(locations=['3303,BREAKAWAY CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3303-BREAKAWAY CREEK")
df_out = api.search(locations=['3304,BESSIEBELLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3304-BESSIEBELLE")
df_out = api.search(locations=['3305,ALLESTREE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3305-ALLESTREE")
df_out = api.search(locations=['3309,DIGBY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3309-DIGBY")
df_out = api.search(locations=['3310,MERINO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3310-MERINO")
df_out = api.search(locations=['3311,CASTERTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3311-CASTERTON")
df_out = api.search(locations=['3312,BAHGALLAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3312-BAHGALLAH")
df_out = api.search(locations=['3314,BULART'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3314-BULART")
df_out = api.search(locations=['3315,BRIT BRIT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3315-BRIT BRIT")
df_out = api.search(locations=['3317,HARROW'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3317-HARROW")
df_out = api.search(locations=['3318,CHARAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3318-CHARAM")
df_out = api.search(locations=['3319,APSLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3319-APSLEY")
df_out = api.search(locations=['3321,HESSE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3321-HESSE")
df_out = api.search(locations=['3322,CRESSY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3322-CRESSY")
df_out = api.search(locations=['3323,BERRYBANK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3323-BERRYBANK")
df_out = api.search(locations=['3324,LISMORE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3324-LISMORE")
df_out = api.search(locations=['3325,DERRINALLUM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3325-DERRINALLUM")
df_out = api.search(locations=['3328,TEESDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3328-TEESDALE")
df_out = api.search(locations=['3329,BARUNAH PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3329-BARUNAH PARK")
df_out = api.search(locations=['3330,ROKEWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3330-ROKEWOOD")
df_out = api.search(locations=['3331,BANNOCKBURN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3331-BANNOCKBURN")
df_out = api.search(locations=['3332,LETHBRIDGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3332-LETHBRIDGE")
df_out = api.search(locations=['3333,BAMGANIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3333-BAMGANIE")
df_out = api.search(locations=['3334,BUNGAL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3334-BUNGAL")
df_out = api.search(locations=['3335,BONNIE BROOK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3335-BONNIE BROOK")
df_out = api.search(locations=['3336,AINTREE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3336-AINTREE")
df_out = api.search(locations=['3337,HARKNESS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3337-HARKNESS")
df_out = api.search(locations=['3338,BROOKFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3338-BROOKFIELD")
df_out = api.search(locations=['3340,BACCHUS MARSH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3340-BACCHUS MARSH")
df_out = api.search(locations=['3341,DALES CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3341-DALES CREEK")
df_out = api.search(locations=['3342,BALLAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3342-BALLAN")
df_out = api.search(locations=['3345,GORDON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3345-GORDON")
df_out = api.search(locations=['3350,ALFREDTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3350-ALFREDTON")
df_out = api.search(locations=['3351,BERRINGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3351-BERRINGA")
df_out = api.search(locations=['3352,ADDINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3352-ADDINGTON")
df_out = api.search(locations=['3355,LAKE GARDENS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3355-LAKE GARDENS")
df_out = api.search(locations=['3356,BONSHAW'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3356-BONSHAW")
df_out = api.search(locations=['3357,BUNINYONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3357-BUNINYONG")
df_out = api.search(locations=['3358,WINTER VALLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3358-WINTER VALLEY")
df_out = api.search(locations=['3360,HAPPY VALLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3360-HAPPY VALLEY")
df_out = api.search(locations=['3361,BRADVALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3361-BRADVALE")
df_out = api.search(locations=['3363,CRESWICK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3363-CRESWICK")
df_out = api.search(locations=['3364,ALLENDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3364-ALLENDALE")
df_out = api.search(locations=['3370,CLUNES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3370-CLUNES")
df_out = api.search(locations=['3371,AMHERST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3371-AMHERST")
df_out = api.search(locations=['3373,BEAUFORT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3373-BEAUFORT")
df_out = api.search(locations=['3375,BALLYROGAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3375-BALLYROGAN")
df_out = api.search(locations=['3377,AMPHITHEATRE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3377-AMPHITHEATRE")
df_out = api.search(locations=['3378,TATYOON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3378-TATYOON")
df_out = api.search(locations=['3379,BERRAMBOOL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3379-BERRAMBOOL")
df_out = api.search(locations=['3380,BELLELLEN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3380-BELLELLEN")
df_out = api.search(locations=['3381,BARKLY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3381-BARKLY")
df_out = api.search(locations=['3384,BARKLY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3384-BARKLY")
df_out = api.search(locations=['3385,DADSWELLS BRIDGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3385-DADSWELLS BRIDGE")
df_out = api.search(locations=['3387,BOLANGUM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3387-BOLANGUM")
df_out = api.search(locations=['3388,BANYENA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3388-BANYENA")
df_out = api.search(locations=['3390,KEWELL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3390-KEWELL")
df_out = api.search(locations=['3391,BRIM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3391-BRIM")
df_out = api.search(locations=['3392,BOOLITE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3392-BOOLITE")
df_out = api.search(locations=['3393,AILSA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3393-AILSA")
df_out = api.search(locations=['3395,BEULAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3395-BEULAH")
df_out = api.search(locations=['3396,HOPETOUN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3396-HOPETOUN")
df_out = api.search(locations=['3400,BRIMPAEN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3400-BRIMPAEN")
df_out = api.search(locations=['3401,BLACKHEATH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3401-BLACKHEATH")
df_out = api.search(locations=['3407,BALMORAL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3407-BALMORAL")
df_out = api.search(locations=['3409,ARAPILES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3409-ARAPILES")
df_out = api.search(locations=['3412,GOROKE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3412-GOROKE")
df_out = api.search(locations=['3413,MINIMAY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3413-MINIMAY")
df_out = api.search(locations=['3414,ANTWERP'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3414-ANTWERP")
df_out = api.search(locations=['3415,MIRAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3415-MIRAM")
df_out = api.search(locations=['3418,BROUGHTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3418-BROUGHTON")
df_out = api.search(locations=['3419,KANIVA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3419-KANIVA")
df_out = api.search(locations=['3420,LILLIMUR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3420-LILLIMUR")
df_out = api.search(locations=['3423,JEPARIT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3423-JEPARIT")
df_out = api.search(locations=['3424,ALBACUTYA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3424-ALBACUTYA")
df_out = api.search(locations=['3427,DIGGERS REST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3427-DIGGERS REST")
df_out = api.search(locations=['3428,BULLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3428-BULLA")
df_out = api.search(locations=['3429,SUNBURY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3429-SUNBURY")
df_out = api.search(locations=['3430,CLARKEFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3430-CLARKEFIELD")
df_out = api.search(locations=['3431,RIDDELLS CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3431-RIDDELLS CREEK")
df_out = api.search(locations=['3432,BOLINDA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3432-BOLINDA")
df_out = api.search(locations=['3434,CHEROKEE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3434-CHEROKEE")
df_out = api.search(locations=['3435,BENLOCH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3435-BENLOCH")
df_out = api.search(locations=['3437,BULLENGAROOK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3437-BULLENGAROOK")
df_out = api.search(locations=['3438,NEW GISBORNE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3438-NEW GISBORNE")
df_out = api.search(locations=['3440,MACEDON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3440-MACEDON")
df_out = api.search(locations=['3441,MOUNT MACEDON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3441-MOUNT MACEDON")
df_out = api.search(locations=['3442,ASHBOURNE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3442-ASHBOURNE")
df_out = api.search(locations=['3444,BARFOLD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3444-BARFOLD")
df_out = api.search(locations=['3446,DRUMMOND NORTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3446-DRUMMOND NORTH")
df_out = api.search(locations=['3447,TARADALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3447-TARADALE")
df_out = api.search(locations=['3448,ELPHINSTONE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3448-ELPHINSTONE")
df_out = api.search(locations=['3450,CASTLEMAINE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3450-CASTLEMAINE")
df_out = api.search(locations=['3451,BARKERS CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3451-BARKERS CREEK")
df_out = api.search(locations=['3453,HARCOURT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3453-HARCOURT")
df_out = api.search(locations=['3458,BARRYS REEF'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3458-BARRYS REEF")
df_out = api.search(locations=['3460,BASALT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3460-BASALT")
df_out = api.search(locations=['3461,BULLARTO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3461-BULLARTO")
df_out = api.search(locations=['3462,GREEN GULLY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3462-GREEN GULLY")
df_out = api.search(locations=['3463,BARINGHUP'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3463-BARINGHUP")
df_out = api.search(locations=['3464,CARISBROOK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3464-CARISBROOK")
df_out = api.search(locations=['3465,ADELAIDE LEAD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3465-ADELAIDE LEAD")
df_out = api.search(locations=['3467,AVOCA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3467-AVOCA")
df_out = api.search(locations=['3468,AMPHITHEATRE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3468-AMPHITHEATRE")
df_out = api.search(locations=['3469,ELMHURST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3469-ELMHURST")
df_out = api.search(locations=['3472,BET BET'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3472-BET BET")
df_out = api.search(locations=['3475,ARCHDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3475-ARCHDALE")
df_out = api.search(locations=['3478,AVON PLAINS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3478-AVON PLAINS")
df_out = api.search(locations=['3480,AREEGRA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3480-AREEGRA")
df_out = api.search(locations=['3482,MASSEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3482-MASSEY")
df_out = api.search(locations=['3483,BALLAPUR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3483-BALLAPUR")
df_out = api.search(locations=['3485,BANYAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3485-BANYAN")
df_out = api.search(locations=['3487,LASCELLES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3487-LASCELLES")
df_out = api.search(locations=['3488,SPEED'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3488-SPEED")
df_out = api.search(locations=['3489,TEMPY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3489-TEMPY")
df_out = api.search(locations=['3490,BIG DESERT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3490-BIG DESERT")
df_out = api.search(locations=['3491,PATCHEWOLLOCK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3491-PATCHEWOLLOCK")
df_out = api.search(locations=['3494,CARWARP'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3494-CARWARP")
df_out = api.search(locations=['3496,CARDROSS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3496-CARDROSS")
df_out = api.search(locations=['3498,IRYMPLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3498-IRYMPLE")
df_out = api.search(locations=['3500,MILDURA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3500-MILDURA")
df_out = api.search(locations=['3501,HATTAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3501-HATTAH")
df_out = api.search(locations=['3505,BIRDWOODTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3505-BIRDWOODTON")
df_out = api.search(locations=['3506,COWANGIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3506-COWANGIE")
df_out = api.search(locations=['3507,WALPEUP'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3507-WALPEUP")
df_out = api.search(locations=['3509,LINGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3509-LINGA")
df_out = api.search(locations=['3512,CARINA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3512-CARINA")
df_out = api.search(locations=['3515,MARONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3515-MARONG")
df_out = api.search(locations=['3516,BRIDGEWATER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3516-BRIDGEWATER")
df_out = api.search(locations=['3517,BEARS LAGOON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3517-BEARS LAGOON")
df_out = api.search(locations=['3518,BERRIMAL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3518-BERRIMAL")
df_out = api.search(locations=['3520,KINYPANIAL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3520-KINYPANIAL")
df_out = api.search(locations=['3521,PYALONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3521-PYALONG")
df_out = api.search(locations=['3522,EMU FLAT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3522-EMU FLAT")
df_out = api.search(locations=['3523,ARGYLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3523-ARGYLE")
df_out = api.search(locations=['3525,BARRAKEE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3525-BARRAKEE")
df_out = api.search(locations=['3527,BUNGULUKE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3527-BUNGULUKE")
df_out = api.search(locations=['3529,KALPIENUNG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3529-KALPIENUNG")
df_out = api.search(locations=['3530,CULGOA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3530-CULGOA")
df_out = api.search(locations=['3531,BERRIWILLOCK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3531-BERRIWILLOCK")
df_out = api.search(locations=['3533,BIMBOURIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3533-BIMBOURIE")
df_out = api.search(locations=['3537,BARRAPORT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3537-BARRAPORT")
df_out = api.search(locations=['3540,CANNIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3540-CANNIE")
df_out = api.search(locations=['3542,COKUM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3542-COKUM")
df_out = api.search(locations=['3544,CHINANGIN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3544-CHINANGIN")
df_out = api.search(locations=['3546,BOLTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3546-BOLTON")
df_out = api.search(locations=['3549,ANNUELLO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3549-ANNUELLO")
df_out = api.search(locations=['3550,BENDIGO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3550-BENDIGO")
df_out = api.search(locations=['3551,ARNOLD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3551-ARNOLD")
df_out = api.search(locations=['3555,BIG HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3555-BIG HILL")
df_out = api.search(locations=['3556,CALIFORNIA GULLY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3556-CALIFORNIA GULLY")
df_out = api.search(locations=['3557,BARNADOWN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3557-BARNADOWN")
df_out = api.search(locations=['3558,BURNEWANG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3558-BURNEWANG")
df_out = api.search(locations=['3559,AVONMORE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3559-AVONMORE")
df_out = api.search(locations=['3561,BALLENDELLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3561-BALLENDELLA")
df_out = api.search(locations=['3562,TORRUMBARRY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3562-TORRUMBARRY")
df_out = api.search(locations=['3563,LOCKINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3563-LOCKINGTON")
df_out = api.search(locations=['3564,BAMAWM EXTENSION'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3564-BAMAWM EXTENSION")
df_out = api.search(locations=['3565,KOTTA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3565-KOTTA")
df_out = api.search(locations=['3566,GUNBOWER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3566-GUNBOWER")
df_out = api.search(locations=['3567,HORFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3567-HORFIELD")
df_out = api.search(locations=['3568,BURKES BRIDGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3568-BURKES BRIDGE")
df_out = api.search(locations=['3570,AUCHMORE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3570-AUCHMORE")
df_out = api.search(locations=['3571,DINGEE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3571-DINGEE")
df_out = api.search(locations=['3572,MILLOO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3572-MILLOO")
df_out = api.search(locations=['3573,CALIVIL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3573-CALIVIL")
df_out = api.search(locations=['3575,BALD ROCK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3575-BALD ROCK")
df_out = api.search(locations=['3576,DURHAM OX'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3576-DURHAM OX")
df_out = api.search(locations=['3579,APPIN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3579-APPIN")
df_out = api.search(locations=['3580,KOONDROOK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3580-KOONDROOK")
df_out = api.search(locations=['3581,BEAUCHAMP'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3581-BEAUCHAMP")
df_out = api.search(locations=['3583,TRESCO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3583-TRESCO")
df_out = api.search(locations=['3584,LAKE BOGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3584-LAKE BOGA")
df_out = api.search(locations=['3585,CASTLE DONNINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3585-CASTLE DONNINGTON")
df_out = api.search(locations=['3586,BULGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3586-BULGA")
df_out = api.search(locations=['3588,WOORINEN SOUTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3588-WOORINEN SOUTH")
df_out = api.search(locations=['3589,WOORINEN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3589-WOORINEN")
df_out = api.search(locations=['3590,BEVERFORD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3590-BEVERFORD")
df_out = api.search(locations=['3591,VINIFERA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3591-VINIFERA")
df_out = api.search(locations=['3594,NYAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3594-NYAH")
df_out = api.search(locations=['3595,NYAH WEST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3595-NYAH WEST")
df_out = api.search(locations=['3596,MIRALIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3596-MIRALIE")
df_out = api.search(locations=['3597,KENLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3597-KENLEY")
df_out = api.search(locations=['3599,BOUNDARY BEND'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3599-BOUNDARY BEND")
df_out = api.search(locations=['3607,TABILK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3607-TABILK")
df_out = api.search(locations=['3608,BAILIESTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3608-BAILIESTON")
df_out = api.search(locations=['3610,DHURRINGILE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3610-DHURRINGILE")
df_out = api.search(locations=['3612,MOORA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3612-MOORA")
df_out = api.search(locations=['3614,TOOLAMBA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3614-TOOLAMBA")
df_out = api.search(locations=['3616,COOMA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3616-COOMA")
df_out = api.search(locations=['3617,BYRNESIDE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3617-BYRNESIDE")
df_out = api.search(locations=['3618,MERRIGUM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3618-MERRIGUM")
df_out = api.search(locations=['3620,KYABRAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3620-KYABRAM")
df_out = api.search(locations=['3621,KOYUGA SOUTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3621-KOYUGA SOUTH")
df_out = api.search(locations=['3622,CORNELIA CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3622-CORNELIA CREEK")
df_out = api.search(locations=['3623,CARAG CARAG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3623-CARAG CARAG")
df_out = api.search(locations=['3624,GIRGARRE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3624-GIRGARRE")
df_out = api.search(locations=['3629,ARDMONA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3629-ARDMONA")
df_out = api.search(locations=['3630,BENARCH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3630-BENARCH")
df_out = api.search(locations=['3631,ARCADIA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3631-ARCADIA")
df_out = api.search(locations=['3633,CONGUPNA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3633-CONGUPNA")
df_out = api.search(locations=['3634,BUNBARTHA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3634-BUNBARTHA")
df_out = api.search(locations=['3635,KAARIMBA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3635-KAARIMBA")
df_out = api.search(locations=['3636,DRUMANURE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3636-DRUMANURE")
df_out = api.search(locations=['3637,WAAIA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3637-WAAIA")
df_out = api.search(locations=['3638,KOTUPNA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3638-KOTUPNA")
df_out = api.search(locations=['3639,BARMAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3639-BARMAH")
df_out = api.search(locations=['3640,KATUNGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3640-KATUNGA")
df_out = api.search(locations=['3641,BEARII'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3641-BEARII")
df_out = api.search(locations=['3644,BAROOGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3644-BAROOGA")
df_out = api.search(locations=['3646,DOOKIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3646-DOOKIE")
df_out = api.search(locations=['3649,KATAMATITE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3649-KATAMATITE")
df_out = api.search(locations=['3658,BROADFORD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3658-BROADFORD")
df_out = api.search(locations=['3659,SUGARLOAF CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3659-SUGARLOAF CREEK")
df_out = api.search(locations=['3660,CAVEAT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3660-CAVEAT")
df_out = api.search(locations=['3662,PUCKAPUNYAL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3662-PUCKAPUNYAL")
df_out = api.search(locations=['3663,MANGALORE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3663-MANGALORE")
df_out = api.search(locations=['3664,AVENEL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3664-AVENEL")
df_out = api.search(locations=['3665,LOCKSLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3665-LOCKSLEY")
df_out = api.search(locations=['3666,BALMATTUM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3666-BALMATTUM")
df_out = api.search(locations=['3669,BOHO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3669-BOHO")
df_out = api.search(locations=['3670,BADDAGINNIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3670-BADDAGINNIE")
df_out = api.search(locations=['3672,BENALLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3672-BENALLA")
df_out = api.search(locations=['3673,BENALLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3673-BENALLA")
df_out = api.search(locations=['3675,BOWEYA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3675-BOWEYA")
df_out = api.search(locations=['3677,APPIN PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3677-APPIN PARK")
df_out = api.search(locations=['3678,BOBINAWARRAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3678-BOBINAWARRAH")
df_out = api.search(locations=['3682,BORALMA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3682-BORALMA")
df_out = api.search(locations=['3683,CHILTERN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3683-CHILTERN")
df_out = api.search(locations=['3685,BOORHAMAN NORTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3685-BOORHAMAN NORTH")
df_out = api.search(locations=['3687,CARLYLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3687-CARLYLE")
df_out = api.search(locations=['3688,BARNAWARTHA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3688-BARNAWARTHA")
df_out = api.search(locations=['3690,WEST WODONGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3690-WEST WODONGA")
df_out = api.search(locations=['3691,ALLANS FLAT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3691-ALLANS FLAT")
df_out = api.search(locations=['3694,BANDIANA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3694-BANDIANA")
df_out = api.search(locations=['3695,CHARLEROI'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3695-CHARLEROI")
df_out = api.search(locations=['3697,TAWONGA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3697-TAWONGA")
df_out = api.search(locations=['3699,BOGONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3699-BOGONG")
df_out = api.search(locations=['3700,BULLIOH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3700-BULLIOH")
df_out = api.search(locations=['3701,DARTMOUTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3701-DARTMOUTH")
df_out = api.search(locations=['3704,KOETONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3704-KOETONG")
df_out = api.search(locations=['3705,CUDGEWA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3705-CUDGEWA")
df_out = api.search(locations=['3707,BIGGARA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3707-BIGGARA")
df_out = api.search(locations=['3708,TINTALDRA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3708-TINTALDRA")
df_out = api.search(locations=['3709,BURROWYE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3709-BURROWYE")
df_out = api.search(locations=['3711,BUXTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3711-BUXTON")
df_out = api.search(locations=['3712,RUBICON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3712-RUBICON")
df_out = api.search(locations=['3713,EILDON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3713-EILDON")
df_out = api.search(locations=['3714,ACHERON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3714-ACHERON")
df_out = api.search(locations=['3715,ANCONA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3715-ANCONA")
df_out = api.search(locations=['3717,FLOWERDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3717-FLOWERDALE")
df_out = api.search(locations=['3718,MOLESWORTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3718-MOLESWORTH")
df_out = api.search(locations=['3719,GOBUR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3719-GOBUR")
df_out = api.search(locations=['3720,BONNIE DOON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3720-BONNIE DOON")
df_out = api.search(locations=['3722,BARWITE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3722-BARWITE")
df_out = api.search(locations=['3723,ARCHERTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3723-ARCHERTON")
df_out = api.search(locations=['3725,BOXWOOD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3725-BOXWOOD")
df_out = api.search(locations=['3726,BUNGEET'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3726-BUNGEET")
df_out = api.search(locations=['3727,ALMONDS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3727-ALMONDS")
df_out = api.search(locations=['3728,BOOMAHNOOMOONAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3728-BOOMAHNOOMOONAH")
df_out = api.search(locations=['3730,BATHUMI'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3730-BATHUMI")
df_out = api.search(locations=['3732,MOYHU'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3732-MOYHU")
df_out = api.search(locations=['3733,WHITFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3733-WHITFIELD")
df_out = api.search(locations=['3735,BOWMANS FOREST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3735-BOWMANS FOREST")
df_out = api.search(locations=['3737,ABBEYARD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3737-ABBEYARD")
df_out = api.search(locations=['3738,OVENS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3738-OVENS")
df_out = api.search(locations=['3739,EUROBIN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3739-EUROBIN")
df_out = api.search(locations=['3740,BUCKLAND'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3740-BUCKLAND")
df_out = api.search(locations=['3741,BRIGHT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3741-BRIGHT")
df_out = api.search(locations=['3744,WANDILIGONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3744-WANDILIGONG")
df_out = api.search(locations=['3746,ELDORADO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3746-ELDORADO")
df_out = api.search(locations=['3747,BAARMUTHA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3747-BAARMUTHA")
df_out = api.search(locations=['3749,BRUARONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3749-BRUARONG")
df_out = api.search(locations=['3750,WOLLERT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3750-WOLLERT")
df_out = api.search(locations=['3751,WOODSTOCK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3751-WOODSTOCK")
df_out = api.search(locations=['3752,MORANG SOUTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3752-MORANG SOUTH")
df_out = api.search(locations=['3753,BEVERIDGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3753-BEVERIDGE")
df_out = api.search(locations=['3754,DOREEN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3754-DOREEN")
df_out = api.search(locations=['3755,YAN YEAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3755-YAN YEAN")
df_out = api.search(locations=['3756,CHINTIN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3756-CHINTIN")
df_out = api.search(locations=['3757,BRUCES CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3757-BRUCES CREEK")
df_out = api.search(locations=['3758,HEATHCOTE JUNCTION'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3758-HEATHCOTE JUNCTION")
df_out = api.search(locations=['3759,PANTON HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3759-PANTON HILL")
df_out = api.search(locations=['3760,SMITHS GULLY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3760-SMITHS GULLY")
df_out = api.search(locations=['3763,KINGLAKE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3763-KINGLAKE")
df_out = api.search(locations=['3764,FORBES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3764-FORBES")
df_out = api.search(locations=['3765,MONTROSE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3765-MONTROSE")
df_out = api.search(locations=['3766,KALORAMA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3766-KALORAMA")
df_out = api.search(locations=['3767,MOUNT DANDENONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3767-MOUNT DANDENONG")
df_out = api.search(locations=['3770,COLDSTREAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3770-COLDSTREAM")
df_out = api.search(locations=['3775,CHRISTMAS HILLS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3775-CHRISTMAS HILLS")
df_out = api.search(locations=['3777,BADGER CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3777-BADGER CREEK")
df_out = api.search(locations=['3778,FERNSHAW'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3778-FERNSHAW")
df_out = api.search(locations=['3779,CAMBARVILLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3779-CAMBARVILLE")
df_out = api.search(locations=['3781,COCKATOO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3781-COCKATOO")
df_out = api.search(locations=['3782,AVONSLEIGH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3782-AVONSLEIGH")
df_out = api.search(locations=['3783,GEMBROOK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3783-GEMBROOK")
df_out = api.search(locations=['3785,TREMONT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3785-TREMONT")
df_out = api.search(locations=['3786,FERNY CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3786-FERNY CREEK")
df_out = api.search(locations=['3787,SASSAFRAS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3787-SASSAFRAS")
df_out = api.search(locations=['3788,OLINDA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3788-OLINDA")
df_out = api.search(locations=['3789,SHERBROOKE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3789-SHERBROOKE")
df_out = api.search(locations=['3791,KALLISTA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3791-KALLISTA")
df_out = api.search(locations=['3792,THE PATCH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3792-THE PATCH")
df_out = api.search(locations=['3793,MONBULK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3793-MONBULK")
df_out = api.search(locations=['3795,SILVAN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3795-SILVAN")
df_out = api.search(locations=['3796,MOUNT EVELYN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3796-MOUNT EVELYN")
df_out = api.search(locations=['3797,GILDEROY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3797-GILDEROY")
df_out = api.search(locations=['3799,BIG PATS CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3799-BIG PATS CREEK")
df_out = api.search(locations=['3800,MONASH UNIVERSITY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3800-MONASH UNIVERSITY")
df_out = api.search(locations=['3802,ENDEAVOUR HILLS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3802-ENDEAVOUR HILLS")
df_out = api.search(locations=['3803,HALLAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3803-HALLAM")
df_out = api.search(locations=['3804,NARRE WARREN EAST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3804-NARRE WARREN EAST")
df_out = api.search(locations=['3805,FOUNTAIN GATE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3805-FOUNTAIN GATE")
df_out = api.search(locations=['3806,BERWICK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3806-BERWICK")
df_out = api.search(locations=['3807,BEACONSFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3807-BEACONSFIELD")
df_out = api.search(locations=['3808,BEACONSFIELD UPPER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3808-BEACONSFIELD UPPER")
df_out = api.search(locations=['3809,OFFICER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3809-OFFICER")
df_out = api.search(locations=['3810,PAKENHAM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3810-PAKENHAM")
df_out = api.search(locations=['3812,MARYKNOLL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3812-MARYKNOLL")
df_out = api.search(locations=['3813,TYNONG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3813-TYNONG")
df_out = api.search(locations=['3814,CORA LYNN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3814-CORA LYNN")
df_out = api.search(locations=['3815,BUNYIP'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3815-BUNYIP")
df_out = api.search(locations=['3816,LABERTOUCHE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3816-LABERTOUCHE")
df_out = api.search(locations=['3818,ATHLONE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3818-ATHLONE")
df_out = api.search(locations=['3820,BONA VISTA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3820-BONA VISTA")
df_out = api.search(locations=['3821,BRANDY CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3821-BRANDY CREEK")
df_out = api.search(locations=['3822,CLOVERLEA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3822-CLOVERLEA")
df_out = api.search(locations=['3823,ALLAMBEE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3823-ALLAMBEE")
df_out = api.search(locations=['3824,CHILDERS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3824-CHILDERS")
df_out = api.search(locations=['3825,ABERFELDY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3825-ABERFELDY")
df_out = api.search(locations=['3831,NEERIM'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3831-NEERIM")
df_out = api.search(locations=['3832,NAYOOK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3832-NAYOOK")
df_out = api.search(locations=['3833,ADA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3833-ADA")
df_out = api.search(locations=['3835,THORPDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3835-THORPDALE")
df_out = api.search(locations=['3840,DRIFFIELD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3840-DRIFFIELD")
df_out = api.search(locations=['3842,CHURCHILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3842-CHURCHILL")
df_out = api.search(locations=['3844,BLACKWARRY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3844-BLACKWARRY")
df_out = api.search(locations=['3847,HIAMDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3847-HIAMDALE")
df_out = api.search(locations=['3850,GIFFARD'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3850-GIFFARD")
df_out = api.search(locations=['3851,AIRLY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3851-AIRLY")
df_out = api.search(locations=['3852,EAST SALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3852-EAST SALE")
df_out = api.search(locations=['3854,GLENGARRY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3854-GLENGARRY")
df_out = api.search(locations=['3856,TOONGABBIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3856-TOONGABBIE")
df_out = api.search(locations=['3857,COWWARR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3857-COWWARR")
df_out = api.search(locations=['3858,ARBUCKLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3858-ARBUCKLE")
df_out = api.search(locations=['3859,MAFFRA WEST UPPER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3859-MAFFRA WEST UPPER")
df_out = api.search(locations=['3860,BOISDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3860-BOISDALE")
df_out = api.search(locations=['3862,BUDGEE BUDGEE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3862-BUDGEE BUDGEE")
df_out = api.search(locations=['3864,FERNBANK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3864-FERNBANK")
df_out = api.search(locations=['3865,LINDENOW'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3865-LINDENOW")
df_out = api.search(locations=['3869,JUMBUK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3869-JUMBUK")
df_out = api.search(locations=['3870,BOOLARRA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3870-BOOLARRA")
df_out = api.search(locations=['3871,ALLAMBEE RESERVE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3871-ALLAMBEE RESERVE")
df_out = api.search(locations=['3873,GORMANDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3873-GORMANDALE")
df_out = api.search(locations=['3874,CARRAJUNG SOUTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3874-CARRAJUNG SOUTH")
df_out = api.search(locations=['3875,BAIRNSDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3875-BAIRNSDALE")
df_out = api.search(locations=['3878,EAGLE POINT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3878-EAGLE POINT")
df_out = api.search(locations=['3880,BOOLE POOLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3880-BOOLE POOLE")
df_out = api.search(locations=['3882,NICHOLSON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3882-NICHOLSON")
df_out = api.search(locations=['3885,BRUMBY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3885-BRUMBY")
df_out = api.search(locations=['3886,NEWMERELLA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3886-NEWMERELLA")
df_out = api.search(locations=['3887,LAKE TYERS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3887-LAKE TYERS")
df_out = api.search(locations=['3888,BENDOC'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3888-BENDOC")
df_out = api.search(locations=['3889,BELL BIRD CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3889-BELL BIRD CREEK")
df_out = api.search(locations=['3890,BULDAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3890-BULDAH")
df_out = api.search(locations=['3891,GENOA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3891-GENOA")
df_out = api.search(locations=['3892,MALLACOOTA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3892-MALLACOOTA")
df_out = api.search(locations=['3893,DOUBLE BRIDGES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3893-DOUBLE BRIDGES")
df_out = api.search(locations=['3895,DOCTORS FLAT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3895-DOCTORS FLAT")
df_out = api.search(locations=['3896,BINDI'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3896-BINDI")
df_out = api.search(locations=['3898,ANGLERS REST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3898-ANGLERS REST")
df_out = api.search(locations=['3900,BENAMBRA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3900-BENAMBRA")
df_out = api.search(locations=['3902,BUMBERRAH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3902-BUMBERRAH")
df_out = api.search(locations=['3903,SWAN REACH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3903-SWAN REACH")
df_out = api.search(locations=['3904,METUNG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3904-METUNG")
df_out = api.search(locations=['3909,KALIMNA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3909-KALIMNA")
df_out = api.search(locations=['3910,LANGWARRIN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3910-LANGWARRIN")
df_out = api.search(locations=['3911,BAXTER'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3911-BAXTER")
df_out = api.search(locations=['3912,PEARCEDALE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3912-PEARCEDALE")
df_out = api.search(locations=['3913,TYABB'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3913-TYABB")
df_out = api.search(locations=['3915,HASTINGS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3915-HASTINGS")
df_out = api.search(locations=['3916,MERRICKS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3916-MERRICKS")
df_out = api.search(locations=['3918,BITTERN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3918-BITTERN")
df_out = api.search(locations=['3919,CRIB POINT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3919-CRIB POINT")
df_out = api.search(locations=['3921,ELIZABETH ISLAND'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3921-ELIZABETH ISLAND")
df_out = api.search(locations=['3922,COWES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3922-COWES")
df_out = api.search(locations=['3923,RHYLL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3923-RHYLL")
df_out = api.search(locations=['3925,CAPE WOOLAMAI'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3925-CAPE WOOLAMAI")
df_out = api.search(locations=['3926,BALNARRING'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3926-BALNARRING")
df_out = api.search(locations=['3927,SOMERS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3927-SOMERS")
df_out = api.search(locations=['3928,MAIN RIDGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3928-MAIN RIDGE")
df_out = api.search(locations=['3929,FLINDERS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3929-FLINDERS")
df_out = api.search(locations=['3930,KUNYUNG'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3930-KUNYUNG")
df_out = api.search(locations=['3931,MORNINGTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3931-MORNINGTON")
df_out = api.search(locations=['3933,MOOROODUC'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3933-MOOROODUC")
df_out = api.search(locations=['3934,MOUNT MARTHA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3934-MOUNT MARTHA")
df_out = api.search(locations=['3936,ARTHURS SEAT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3936-ARTHURS SEAT")
df_out = api.search(locations=['3937,RED HILL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3937-RED HILL")
df_out = api.search(locations=['3938,MCCRAE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3938-MCCRAE")
df_out = api.search(locations=['3939,BONEO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3939-BONEO")
df_out = api.search(locations=['3940,CAPEL SOUND'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3940-CAPEL SOUND")
df_out = api.search(locations=['3941,RYE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3941-RYE")
df_out = api.search(locations=['3942,BLAIRGOWRIE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3942-BLAIRGOWRIE")
df_out = api.search(locations=['3943,SORRENTO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3943-SORRENTO")
df_out = api.search(locations=['3944,PORTSEA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3944-PORTSEA")
df_out = api.search(locations=['3945,BELLVIEW'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3945-BELLVIEW")
df_out = api.search(locations=['3946,BENA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3946-BENA")
df_out = api.search(locations=['3950,KARDELLA SOUTH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3950-KARDELLA SOUTH")
df_out = api.search(locations=['3951,ARAWATA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3951-ARAWATA")
df_out = api.search(locations=['3953,BERRYS CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3953-BERRYS CREEK")
df_out = api.search(locations=['3954,KOONWARRA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3954-KOONWARRA")
df_out = api.search(locations=['3956,DUMBALK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3956-DUMBALK")
df_out = api.search(locations=['3957,GRASSY SPUR'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3957-GRASSY SPUR")
df_out = api.search(locations=['3958,BUFFALO'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3958-BUFFALO")
df_out = api.search(locations=['3959,FISH CREEK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3959-FISH CREEK")
df_out = api.search(locations=['3960,BENNISON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3960-BENNISON")
df_out = api.search(locations=['3962,AGNES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3962-AGNES")
df_out = api.search(locations=['3964,PORT FRANKLIN'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3964-PORT FRANKLIN")
df_out = api.search(locations=['3965,PORT WELSHPOOL'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3965-PORT WELSHPOOL")
df_out = api.search(locations=['3966,BINGINWARRI'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3966-BINGINWARRI")
df_out = api.search(locations=['3967,HEDLEY'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3967-HEDLEY")
df_out = api.search(locations=['3971,ALBERTON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3971-ALBERTON")
df_out = api.search(locations=['3975,LYNBROOK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3975-LYNBROOK")
df_out = api.search(locations=['3976,HAMPTON PARK'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3976-HAMPTON PARK")
df_out = api.search(locations=['3977,BOTANIC RIDGE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3977-BOTANIC RIDGE")
df_out = api.search(locations=['3978,CARDINIA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3978-CARDINIA")
df_out = api.search(locations=['3979,ALMURTA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3979-ALMURTA")
df_out = api.search(locations=['3980,BLIND BIGHT'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3980-BLIND BIGHT")
df_out = api.search(locations=['3981,BAYLES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3981-BAYLES")
df_out = api.search(locations=['3984,ADAMS ESTATE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3984-ADAMS ESTATE")
df_out = api.search(locations=['3987,NYORA'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3987-NYORA")
df_out = api.search(locations=['3988,MOUNTAIN VIEW'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3988-MOUNTAIN VIEW")
df_out = api.search(locations=['3990,GLEN FORBES'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3990-GLEN FORBES")
df_out = api.search(locations=['3991,BASS'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3991-BASS")
df_out = api.search(locations=['3992,BLACKWOOD FOREST'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3992-BLACKWOOD FOREST")
df_out = api.search(locations=['3995,ANDERSON'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3995-ANDERSON")
df_out = api.search(locations=['3996,INVERLOCH'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:3996-INVERLOCH")
df_out = api.search(locations=['9999,NORTH POLE'] )
df_out = pd.DataFrame(df_out)
DF_ALL = DF_ALL.append(df_out, ignore_index=True) 
print("finished all:9999-NORTH POLE")

DF_ALL1 = DF_ALL.reset_index()
DF_ALL2 = DF_ALL1.drop(columns=['id','index','images','images_floorplans','listers'])
DF_ALL_UNIQ = DF_ALL2.drop_duplicates()

DF_ALL.to_pickle("/Users/joezhou/Downloads/Realestate/R_ALL_VIC.pkl")
